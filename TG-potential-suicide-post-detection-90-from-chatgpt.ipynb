# %% [markdown]
# # First and foremost, thank you for sharing this dataset.
# # Author: Thomas Gamet licensing under the Apache 2.0 license.
#
# Updated, 90% accuracy with Chat GPT as an LLM performing diagnosis. Cohen's Kappa of 0.78.
# Lesson: ChatGPT hallucinates with conflicting inputs, better results via more specific focus, and prompt design matters. Three minor adjustments were tried, and the result below is consistent for what I've been able to prompt from ChatGPT 3.5 (exact model name is in the code below).
# Both agree on potential suicide post =  541 times.
# Both agree on not suicide post =  1068 times.
# Ground truth says potential suicide post and LLM disagrees =  118 times.
# Ground truth says not a suicide post and LLM disagrees =  58 times.
# Calculated Observed Agreement = 0.9014005602240897
# Calculated Chance Agreement = 0.5430178345848143
# Cohen's Kappa= 0.7842378822676176
#
# Reading https://www.nature.com/articles/s41598-018-25773-2 (Identifying Suicide Ideation and Suicidal Attempts in a Psychiatric Clinical Research Database using Natural Language Processing)
# "The sets were independently classified by all three authors with good inter-rater agreement as indicated by a Cohen’s kappa of 0.85 for suicide ideation and 0.86 for suicide attempt. (See supplementary material for further details on inter-rater agreement and rules: https://github.com/andreafernandes/NLP_Tools_Development). It seems that 86% agreement may be in a gold standard range. I also took a few cues and updated the prompts.
#
# Added a Cohen Kappa calculation with further optimization of the prompts and loops:
# Both agree on potential suicide post =  459 times.
# Both agree on not suicide post =  1100 times.
# Ground truth says potential suicide post and LLM disagrees =  200 times.
# Ground truth says not a suicide post and LLM disagrees =  26 times.
# Calculated Observed Agreement = 0.8733893557422969
# Calculated Chance Agreement = 0.5597266357523402
# Cohen's Kappa= 0.7124271996920467 (this is mid range for generally accepted significant agreement)
#
# There were a total of 226 errors made relative to ground truth.
# Accuracy is at 87.3389355742297 %
#
# The obserer agreement looks good, and Kappa is generally also a good result, even if a bit
# below the gold standard of the article above. For those not familiar with Cohen's Kappa:https://www.statology.org/cohens-kappa-statistic/
#
# I am not sure where an algorithm might be overfitting, but I'm pretty sure a generalized solution
# can only be a little more accurate without being unusually too accurate relative to human on human comparisons and those human on human should be the most generalized comparisons.
#
# Experiment: Loaded 80% of the tweets for similarity matches in a stratified way made only a small change in accuracy with the main difference in the false negatives. Experiments:
# 1. Originally with the LLM deciding on potential suicide posts alone was 82.5% accuracy
# 2. With 80% stratified in the vectorstore the potential suicide post achieved 83.6% accuracy
# 3. Loading 80% of the tweets with potential suicide post status shows 84.6% accuracy
# 4. A prompt improvement aimed at considering depression and becoming tired of life shows 87.3% accuracy
# 5. Updated the prompts to aim at improvements after reading (Identifying Suicide Ideation and Suicidal Attempts in a Psychiatric Clinical Research Database using Natural Language Processing)
#
# The OpenAI ChatGPT LLM heavily seems to favor the probability of saying a large number of ground
# truth cases for potential suicide posts are not suicide posts (shown as false negatives against the ground truth) even when the vector store is indexed with many of the actual data points providing similarity matches for being potential suicide posts.
#
# The prompts were improved, the output made easier to read when confirming the LLMs performance and
# the number of retries needed when the LLM produces unusable results. Also, the results are now
# processed to make sure outputs are valid responses, and exceptoins on dictionary processing are
# handled (keys are found).
#
# ## 1 Use pip to install langchain and Chroma
# ## 2 Load and prepare a dataset for ChatGPT to work upon
# ## 3 Ask ChatGPT to analyze batches of 4 tweets for suicide related ideation
# ## 4 Report False Positives, False Negatives, and overall accuracy (with listing)
# ## 5 Report Cohen's Kappa
# ## 6 Load a VectorstoreIndex with all the tweets to ask inter-tweet questions
# ## 7 Show a few (3) questions and the answers given
#
# You will need to use your own OpenAI API key or change to a 'no cost' LLM.
# Hope this proves useful to some viewer. A full run of this notebook, using
# default setting with ChatGPT 3.5, cost about 0.40 USD per OpenAI's usage information.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/suicidal-tweet-detection-dataset/Suicide_Ideation_Dataset(Twitter-based).csv

# %% [markdown]
# # Several pip installation calls are made

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.0.278-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.17)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain) (0.5.9)
# Collecting langsmith<0.1.0,>=0.0.21 (from langchain)
#   Downloading langsmith-0.0.32-py3-none-any.whl (36 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.10.9)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (3.0.9)
# Installing collected packages: langsmith, langchain
# Successfully installed langchain-0.0.278 langsmith-0.0.32
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.10/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.28.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.8-py3-none-any.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.3/418.3 kB 6.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.28 in /opt/conda/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.10.9)
# Collecting chroma-hnswlib==0.7.2 (from chromadb)
#   Downloading chroma-hnswlib-0.7.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.98.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.23.5)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.6.3)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 50.2 MB/s eta 0:00:0000:0100:01
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 52.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.65.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from chromadb) (5.12.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb) (0.27.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (21.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pulsar-client>=3.1.0->chromadb) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (1.26.15)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.0)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.7.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxruntime>=1.14.1->chromadb) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.1)
# Building wheels for collected packages: chroma-hnswlib, pypika
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.2-cp310-cp310-linux_x86_64.whl size=194635 sha256=978d50fc180c2a4759bd40202e1a222520cea93b8e3bb755d1780cb1fae154ac
#   Stored in directory: /root/.cache/pip/wheels/11/2b/0d/ee457f6782f75315bb5828d5c2dc5639d471afbd44a830b9dc
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=c9d416079acbfc120a945ab4fdde29046f7778125772289befef1ae828847c27
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built chroma-hnswlib pypika
# Installing collected packages: pypika, monotonic, pulsar-client, overrides, humanfriendly, chroma-hnswlib, bcrypt, posthog, coloredlogs, onnxruntime, chromadb
#   Attempting uninstall: overrides
#     Found existing installation: overrides 6.5.0
#     Uninstalling overrides-6.5.0:
#       Successfully uninstalled overrides-6.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-pubsublite 1.8.2 requires overrides<7.0.0,>=6.0.1, but you have overrides 7.4.0 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# Successfully installed bcrypt-4.0.1 chroma-hnswlib-0.7.2 chromadb-0.4.8 coloredlogs-15.0.1 humanfriendly-10.0 monotonic-1.6 onnxruntime-1.15.1 overrides-7.3.1 posthog-3.0.2 pulsar-client-3.3.0 pypika-0.48.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2023.5.7)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load and prepare a dataset for ChatGPT to work upon

# %%
# Step one, get data and supporting modules into place

import pandas as pd
from datasets import Dataset
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.indexes import VectorstoreIndexCreator
from langchain.docstore.document import Document
from langchain.chat_models import ChatOpenAI
import os
import openai
import sys
import ast
import time

dataname = "/kaggle/input/suicidal-tweet-detection-dataset/Suicide_Ideation_Dataset(Twitter-based).csv"
tweet_df = pd.read_csv(dataname)

tweet_df = tweet_df.dropna(subset=['Tweet','Suicide']) # get rid of these
tweet_df = tweet_df.reset_index(drop=True)

ltest_df = tweet_df.copy() # [0:5].copy() # make it small for testing
ltest_df.drop(columns=['Suicide'],inplace=True)

print ("Tweets are loaded and dropna applied to nulls.")
print ("A local test dataframe (ltest_df) is ready for use.")
print ("The shape of ltest_df is",ltest_df.shape)
# Out:
# Tweets are loaded and dropna applied to nulls.
# A local test dataframe (ltest_df) is ready for use.
# The shape of ltest_df is (1785, 1)

# %% [markdown]
# # Prvide the LLM with 80% of the tweets as examples for its categorization
#
# Provide the LLM an Indexed Vectorstore using a typical 80% of the data as training data
# and then ask it to see if it recognized the categorization from the training data when it
# is tested for overall accuracy.

# %%
# Now, to show the power of a vector index, each tweet will be loaded.
# The tweets will be one document each vectorized and with embeddings
# There is no need to split the documents

# However, the prompt are not worded to look for data in this vectorstore

os.environ["OPENAI_API_KEY"] = "sk-"

print ("Provide the LLM with 80% (4 of 5) of the tweets as training knowledge.")
doclist = []
total_not_sui = 0
total_sui = 0
for tweetnum in range(tweet_df.shape[0]): #tweet_df.shape[0]):
    if tweet_df.loc[tweetnum,'Suicide'] == 'Not Suicide post':
        total_not_sui += 1 # skip these
        #if total_not_sui % 5 > 0:
        #    thetweetcase = "Tweets like " + tweet_df.loc[tweetnum,'Tweet'] + " are to be Ignored"
        #    raw_documents = Document(page_content=thetweetcase)
        #    doclist.append(raw_documents)
    else:
        total_sui += 1
        if total_sui % 5 > 0:
            thetweetcase = "Tweets like " + tweet_df.loc[tweetnum,'Tweet'] + " are potential suicide posts to be diagnosed as Follow-up"
            raw_documents = Document(page_content=thetweetcase)
            doclist.append(raw_documents)

print("Loading",len(doclist),"tweets into the VectorstoreIndex as examples.")
index = VectorstoreIndexCreator(vectorstore_kwargs={"persist_directory":None}).from_documents(doclist)
# Out:
# Provide the LLM with 80% (4 of 5) of the tweets as training knowledge.
# Loading 528 tweets into the VectorstoreIndex as examples.

# %% [markdown]
# # Ask ChatGPT to analyze batches of 4 tweets for suicide related ideation
#
# The following prompts failed to deliver over 82% accuracy and Cohen's Kappa over .59
# Reverting prompts and trying one last and more expensive experiment (a batch size of 1 so
# I know the LLM is not mixing tweet contents).
#
#     query = "Given tweets "+ \
#         str(raw_documents) + \
#         "From the perspective of the National Institute of Mental Health " + \
#         "Examine these tweets and assess each if it contains any warning signs of suicide risk. " + \
#         "Pay attention to the language used, any expressions of despair, depression, anxiety, feelings of being trapped or overwhelmed, or mentions of wanting to end one’s life" + \
#         "Also, look for any indications of hopelessness, helplessness, hate, being tired, or worthlessness, as well as any mention of plans or preparations for self-harm. " + \
#         "Take every tweet seriously." + \
#         "Use a diagnosis of Follow-up with any potential things checked for above and use a diagnosis of Ignore when there is no risk. " + \
#         "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
#         " { tweets: [{ tweet_number : x, diagnosis: value}]}."
#     query2 = "Retry tweets "+ \
#         str(raw_documents) + \
#         "From the perspective of the National Institute of Mental Health " + \
#         "Examine these tweets and assess each if it contains any warning signs of suicide risk. " + \
#         "Consider factors such as the language used, the tone of the message, and any references to self-harm, being tired, or self hate." + \
#         "Also, look for any indications of depression, hopelessness, helplessness, or worthlessness, as well as any mention of plans or preparations for self-harm. " + \
#         "Take every tweet seriously." + \
#         "Use a diagnosis of Follow-up with any potential risk factors above and use a diagnosis of Ignore when there is no risk. " + \
#         "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
#         " { tweets: [{ tweet_number : x, diagnosis: value}]}."
#     query3 = "Last try with tweets "+ \
#         str(raw_documents) + \
#         "From the perspective of the National Institute of Mental Health " + \
#         "Evaluate these tweets and determine if it suggests that the individual may be at risk for suicide.  " + \
#         "Pay attention to the language used, any expressions of despair, feelings of being trapped or overwhelmed, or mentions of wanting to end one’s life" + \
#         "Also, look for any indications of hopelessness, helplessness, or worthlessness, as well as any mention of plans or preparations for self-harm. " + \
#         "Take every tweet seriously." + \
#         "Use a diagnosis of Follow-up with any potential risk factors for suicide above and use a diagnosis of Ignore when there is no risk. " + \
#         "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
#         " { tweets: [{ tweet_number : x, diagnosis: value}]}."

# %%
# Now it will ask ChatGPT to analyze each tweet as an independent post for whether they potentially contains suidical wording.
# It will batch the tweets to reduce the number of tokens required, especially since the API is paid for by the tokens used.
# It is not searching for similarities, differences, or otherwise comparing the different tweets, so there is no need to load
# a vector database with documents to search. That is left as an exercise after the false positives and false negatives are 
# reviewed.

import pandas as pd

# we will be checking for any updates that were missed - the values set on the next line are over-ridden
tweet_df['diagnosis'] = tweet_df['Suicide'] # this is a quick way to add a column, next we update with ltest_df's results

BATCH_SIZE = 1
batch_cnt = 1784 # int(ltest_df.shape[0] / BATCH_SIZE)
response = ""
responsedict = {}

for batch in range(batch_cnt):
    raw_documents = Document(page_content=str(ltest_df.loc[batch*BATCH_SIZE:(batch+1)*BATCH_SIZE-1,"Tweet"].to_dict()))
    if batch == batch_cnt - 1: # try to squeeze 5 into the last batch
        raw_documents = Document(page_content=str(ltest_df.loc[batch*BATCH_SIZE:(batch+1)*BATCH_SIZE,"Tweet"].to_dict()))
    print("Processing batch",batch+1,"of",batch_cnt,"batches.") #:",raw_documents)
    query = "Given tweets "+ \
        str(raw_documents) + \
        "Make a diangosis for Follow-up when a tweet " + \
        "has potential suicidal ideations, depression, hopelessness, helplessness, " + \
        "loss of interest in life, or self harm. " + \
        "Use a diagnosis of Ignore when the tweet does not suggest self harm. "+ \
        "It is better have a diagnosis as Follow-up than a diagnosis as Ignore and double check before a diagnosis for Ignore." + \
        "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
        " { tweets: [{ tweet_number : x, diagnosis: value}]}."
    query2 = "Retry tweets "+ \
        str(raw_documents) + \
        "You must use a diagnosis of Follow-up when a tweet " + \
        "has potential suicidal thoughts, depression of any kind, hopelessness, helplessness, deep loss," + \
        "wording that shows a interest in death, or suggests self harm. " + \
        "It is better to offer a diagnosis of Follow-up than a diagnosis of Ignore." + \
        "Otherwise the tweet receives a diagnosis of Ignore. "+ \
        "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
        " { tweets: [{ tweet_number : x, diagnosis: value}]}."
    query3 = "Last try with tweets "+ \
        str(raw_documents) + \
        "Be sure to make a diangosis for Follow-up when a tweet " + \
        "has potential suicidal writing, serious depression, " + \
        "or words that suggest self harm. " + \
        "If the tweet is not a potential suicide post then use a diagnosis of Ignore. "+ \
        "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
        " { tweets: [{ tweet_number : x, diagnosis: value}]}."   # Kept testing affordable
    otryno = 0
    while otryno < 7:
        otryno += 1
        tryno = 0
        if otryno > 4: # attempt at a fail safe last resort - short enough to usually be understood down to its output format
            query = "When answering do so as a python dictionary. Given tweets "+ \
                     str(raw_documents) + \
                "With preference to diagnosis for Follow-up when a tweet " + \
                "has potential suicidal thoughts, depression of any kind, " + \
                "wording that shows a interest in death, or suggests self harm. " + \
                "If the tweet appears not potentially suicidal then use a diagnosis of Ignore. "+ \
                "You must answer as a python dictionary with keys tweet_number and diagnosis in the format "+ \
                " { tweets: [{ tweet_number : x, diagnosis: value}]}." 
        while tryno < 3:
            time.sleep(3) # better to pace internally then by OpenAI via trottling this process
            if tryno == 0:
                response = index.query(query, llm=ChatOpenAI(model_name="gpt-3.5-turbo"))
            elif tryno == 1:
                response = index.query(query2, llm=ChatOpenAI(model_name="gpt-3.5-turbo"))
            else:
                response = index.query(query3, llm=ChatOpenAI(model_name="gpt-3.5-turbo"))
            try:
                responsedict = ast.literal_eval(response)
                tryno = 4 # made it - ast was able to read a dictionary.
            except:
                print("Must retry, on try",tryno+1) # the LLM was a jerk and ignored the must answer format
            tryno += 1
        if tryno > 3:
            tweetlist = responsedict['tweets']
            if len(tweetlist) < 1:
                print("Must retry when the LLM failed to produce all answers, try=",otryno)
                time.sleep(7+otryno) # do not rush, this is a problem with the LLM
            else:
                ootryno = otryno
                otryno = 8 # yes, we will process answers and go to the next set of tweets
                resetRetry = False
                for i in range(len(tweetlist)):
                    diagdict = tweetlist[i]
                    idx = 0
                    try:
                        idx = int(diagdict['tweet_number'])
                    except:
                        otryno = ootryno
                        print("The LLM return a dictionary that does not contain tweet_number")
                        break
                    if idx >= batch*BATCH_SIZE and idx <= batch*BATCH_SIZE+BATCH_SIZE:
                        diag = "Nogo"
                        try:
                            diag = diagdict['diagnosis']
                        except:
                            otryno = ootryno
                            print("The LLM returned a dictionary that does not contain diagnosis")
                            break
                        tweet_df.loc[idx,'diagnosis'] = diag
                        if diag != "Ignore" and diag != "Follow-up":
                            print ("The LLM gave a disqualified diagnosis of ", diag)
                            resetRetry = True
                    else:
                        print ("The LLM made an index error reporting idx=", idx)
                        resetRetry = True
                if resetRetry:
                    otryno = ootryno
    if otryno == 7:
        print("Failed to process this batch!")
print("Completed processing.")
# Out:
# Processing batch 1 of 1784 batches.
# Processing batch 2 of 1784 batches.
# Processing batch 3 of 1784 batches.
# Processing batch 4 of 1784 batches.
# Processing batch 5 of 1784 batches.
# Processing batch 6 of 1784 batches.
# Processing batch 7 of 1784 batches.
# Processing batch 8 of 1784 batches.
# Processing batch 9 of 1784 batches.
# Processing batch 10 of 1784 batches.
# Processing batch 11 of 1784 batches.
# Processing batch 12 of 1784 batches.
# Processing batch 13 of 1784 batches.
# Processing batch 14 of 1784 batches.
# Processing batch 15 of 1784 batches.
# Processing batch 16 of 1784 batches.
# Processing batch 17 of 1784 batches.
# Processing batch 18 of 1784 batches.
# Processing batch 19 of 1784 batches.
# Processing batch 20 of 1784 batches.
# Processing batch 21 of 1784 batches.
# Processing batch 22 of 1784 batches.
# Processing batch 23 of 1784 batches.
# Processing batch 24 of 1784 batches.
# Processing batch 25 of 1784 batches.
# Processing batch 26 of 1784 batches.
# Processing batch 27 of 1784 batches.
# Processing batch 28 of 1784 batches.
# Processing batch 29 of 1784 batches.
# Processing batch 30 of 1784 batches.
# Processing batch 31 of 1784 batches.
# Processing batch 32 of 1784 batches.
# Processing batch 33 of 1784 batches.
# Processing batch 34 of 1784 batches.
# Processing batch 35 of 1784 batches.
# Processing batch 36 of 1784 batches.
# Processing batch 37 of 1784 batches.
# Processing batch 38 of 1784 batches.
# Processing batch 39 of 1784 batches.
# Processing batch 40 of 1784 batches.
# Processing batch 41 of 1784 batches.
# Processing batch 42 of 1784 batches.
# Processing batch 43 of 1784 batches.
# Processing batch 44 of 1784 batches.
# Processing batch 45 of 1784 batches.
# Processing batch 46 of 1784 batches.
# Processing batch 47 of 1784 batches.
# Processing batch 48 of 1784 batches.
# Processing batch 49 of 1784 batches.
# Processing batch 50 of 1784 batches.
# Processing batch 51 of 1784 batches.
# Processing batch 52 of 1784 batches.
# Processing batch 53 of 1784 batches.
# Processing batch 54 of 1784 batches.
# Processing batch 55 of 1784 batches.
# Processing batch 56 of 1784 batches.
# Processing batch 57 of 1784 batches.
# Processing batch 58 of 1784 batches.
# Processing batch 59 of 1784 batches.
# Processing batch 60 of 1784 batches.
# Processing batch 61 of 1784 batches.
# Processing batch 62 of 1784 batches.
# Processing batch 63 of 1784 batches.
# Processing batch 64 of 1784 batches.
# Processing batch 65 of 1784 batches.
# Processing batch 66 of 1784 batches.
# Processing batch 67 of 1784 batches.
# Processing batch 68 of 1784 batches.
# Processing batch 69 of 1784 batches.
# Processing batch 70 of 1784 batches.
# Processing batch 71 of 1784 batches.
# Processing batch 72 of 1784 batches.
# Processing batch 73 of 1784 batches.
# Processing batch 74 of 1784 batches.
# Processing batch 75 of 1784 batches.
# Processing batch 76 of 1784 batches.
# Processing batch 77 of 1784 batches.
# Processing batch 78 of 1784 batches.
# Processing batch 79 of 1784 batches.
# Processing batch 80 of 1784 batches.
# Processing batch 81 of 1784 batches.
# Processing batch 82 of 1784 batches.
# Processing batch 83 of 1784 batches.
# Processing batch 84 of 1784 batches.
# Processing batch 85 of 1784 batches.
# Processing batch 86 of 1784 batches.
# Processing batch 87 of 1784 batches.
# Processing batch 88 of 1784 batches.
# Processing batch 89 of 1784 batches.
# Processing batch 90 of 1784 batches.
# Processing batch 91 of 1784 batches.
# Processing batch 92 of 1784 batches.
# Processing batch 93 of 1784 batches.
# Processing batch 94 of 1784 batches.
# Processing batch 95 of 1784 batches.
# Processing batch 96 of 1784 batches.
# Processing batch 97 of 1784 batches.
# Processing batch 98 of 1784 batches.
# Processing batch 99 of 1784 batches.
# Processing batch 100 of 1784 batches.
# Processing batch 101 of 1784 batches.
# Processing batch 102 of 1784 batches.
# Processing batch 103 of 1784 batches.
# Processing batch 104 of 1784 batches.
# Processing batch 105 of 1784 batches.
# Processing batch 106 of 1784 batches.
# Processing batch 107 of 1784 batches.
# Processing batch 108 of 1784 batches.
# Processing batch 109 of 1784 batches.
# Processing batch 110 of 1784 batches.
# Processing batch 111 of 1784 batches.
# Processing batch 112 of 1784 batches.
# Processing batch 113 of 1784 batches.
# Processing batch 114 of 1784 batches.
# Processing batch 115 of 1784 batches.
# Processing batch 116 of 1784 batches.
# Processing batch 117 of 1784 batches.
# Processing batch 118 of 1784 batches.
# Processing batch 119 of 1784 batches.
# Processing batch 120 of 1784 batches.
# Processing batch 121 of 1784 batches.
# Processing batch 122 of 1784 batches.
# Processing batch 123 of 1784 batches.
# Processing batch 124 of 1784 batches.
# Processing batch 125 of 1784 batches.
# Processing batch 126 of 1784 batches.
# Processing batch 127 of 1784 batches.
# Processing batch 128 of 1784 batches.
# Processing batch 129 of 1784 batches.
# Processing batch 130 of 1784 batches.
# Processing batch 131 of 1784 batches.
# Processing batch 132 of 1784 batches.
# Processing batch 133 of 1784 batches.
# Processing batch 134 of 1784 batches.
# Processing batch 135 of 1784 batches.
# Processing batch 136 of 1784 batches.
# Processing batch 137 of 1784 batches.
# Processing batch 138 of 1784 batches.
# Processing batch 139 of 1784 batches.
# Processing batch 140 of 1784 batches.
# Processing batch 141 of 1784 batches.
# Processing batch 142 of 1784 batches.
# Processing batch 143 of 1784 batches.
# Processing batch 144 of 1784 batches.
# Processing batch 145 of 1784 batches.
# Processing batch 146 of 1784 batches.
# Processing batch 147 of 1784 batches.
# Processing batch 148 of 1784 batches.
# Processing batch 149 of 1784 batches.
# Processing batch 150 of 1784 batches.
# Processing batch 151 of 1784 batches.
# Processing batch 152 of 1784 batches.
# Processing batch 153 of 1784 batches.
# Processing batch 154 of 1784 batches.
# Processing batch 155 of 1784 batches.
# Processing batch 156 of 1784 batches.
# Processing batch 157 of 1784 batches.
# Processing batch 158 of 1784 batches.
# Processing batch 159 of 1784 batches.
# Processing batch 160 of 1784 batches.
# Processing batch 161 of 1784 batches.
# Processing batch 162 of 1784 batches.
# Processing batch 163 of 1784 batches.
# Processing batch 164 of 1784 batches.
# Processing batch 165 of 1784 batches.
# Processing batch 166 of 1784 batches.
# Processing batch 167 of 1784 batches.
# Processing batch 168 of 1784 batches.
# Processing batch 169 of 1784 batches.
# Processing batch 170 of 1784 batches.
# Processing batch 171 of 1784 batches.
# Processing batch 172 of 1784 batches.
# Processing batch 173 of 1784 batches.
# Processing batch 174 of 1784 batches.
# Processing batch 175 of 1784 batches.
# Processing batch 176 of 1784 batches.
# Processing batch 177 of 1784 batches.
# Processing batch 178 of 1784 batches.
# Processing batch 179 of 1784 batches.
# Processing batch 180 of 1784 batches.
# Processing batch 181 of 1784 batches.
# Processing batch 182 of 1784 batches.
# Processing batch 183 of 1784 batches.
# Processing batch 184 of 1784 batches.
# Processing batch 185 of 1784 batches.
# Processing batch 186 of 1784 batches.
# Processing batch 187 of 1784 batches.
# Processing batch 188 of 1784 batches.
# Processing batch 189 of 1784 batches.
# Processing batch 190 of 1784 batches.
# Processing batch 191 of 1784 batches.
# Processing batch 192 of 1784 batches.
# Processing batch 193 of 1784 batches.
# Processing batch 194 of 1784 batches.
# Processing batch 195 of 1784 batches.
# Processing batch 196 of 1784 batches.
# Processing batch 197 of 1784 batches.
# Processing batch 198 of 1784 batches.
# Processing batch 199 of 1784 batches.
# Processing batch 200 of 1784 batches.
# Processing batch 201 of 1784 batches.
# Processing batch 202 of 1784 batches.
# Processing batch 203 of 1784 batches.
# Processing batch 204 of 1784 batches.
# Processing batch 205 of 1784 batches.
# Processing batch 206 of 1784 batches.
# Processing batch 207 of 1784 batches.
# Processing batch 208 of 1784 batches.
# Processing batch 209 of 1784 batches.
# Processing batch 210 of 1784 batches.
# Processing batch 211 of 1784 batches.
# Processing batch 212 of 1784 batches.
# Processing batch 213 of 1784 batches.
# Processing batch 214 of 1784 batches.
# Processing batch 215 of 1784 batches.
# Processing batch 216 of 1784 batches.
# Processing batch 217 of 1784 batches.
# Processing batch 218 of 1784 batches.
# Processing batch 219 of 1784 batches.
# Processing batch 220 of 1784 batches.
# Processing batch 221 of 1784 batches.
# Processing batch 222 of 1784 batches.
# Processing batch 223 of 1784 batches.
# Processing batch 224 of 1784 batches.
# Processing batch 225 of 1784 batches.
# Processing batch 226 of 1784 batches.
# Processing batch 227 of 1784 batches.
# Processing batch 228 of 1784 batches.
# Processing batch 229 of 1784 batches.
# Processing batch 230 of 1784 batches.
# Processing batch 231 of 1784 batches.
# Processing batch 232 of 1784 batches.
# Processing batch 233 of 1784 batches.
# Processing batch 234 of 1784 batches.
# Processing batch 235 of 1784 batches.
# Processing batch 236 of 1784 batches.
# Processing batch 237 of 1784 batches.
# Processing batch 238 of 1784 batches.
# Processing batch 239 of 1784 batches.
# Processing batch 240 of 1784 batches.
# Processing batch 241 of 1784 batches.
# Processing batch 242 of 1784 batches.
# Processing batch 243 of 1784 batches.
# Processing batch 244 of 1784 batches.
# Processing batch 245 of 1784 batches.
# Processing batch 246 of 1784 batches.
# Processing batch 247 of 1784 batches.
# Processing batch 248 of 1784 batches.
# Processing batch 249 of 1784 batches.
# Processing batch 250 of 1784 batches.
# Processing batch 251 of 1784 batches.
# Processing batch 252 of 1784 batches.
# Processing batch 253 of 1784 batches.
# Processing batch 254 of 1784 batches.
# Processing batch 255 of 1784 batches.
# Processing batch 256 of 1784 batches.
# Processing batch 257 of 1784 batches.
# Processing batch 258 of 1784 batches.
# Processing batch 259 of 1784 batches.
# Processing batch 260 of 1784 batches.
# Processing batch 261 of 1784 batches.
# Processing batch 262 of 1784 batches.
# Processing batch 263 of 1784 batches.
# Processing batch 264 of 1784 batches.
# Processing batch 265 of 1784 batches.
# Processing batch 266 of 1784 batches.
# Processing batch 267 of 1784 batches.
# Processing batch 268 of 1784 batches.
# Processing batch 269 of 1784 batches.
# Processing batch 270 of 1784 batches.
# Processing batch 271 of 1784 batches.
# Processing batch 272 of 1784 batches.
# Processing batch 273 of 1784 batches.
# Processing batch 274 of 1784 batches.
# Processing batch 275 of 1784 batches.
# Processing batch 276 of 1784 batches.
# Processing batch 277 of 1784 batches.
# Processing batch 278 of 1784 batches.
# Processing batch 279 of 1784 batches.
# Processing batch 280 of 1784 batches.
# Processing batch 281 of 1784 batches.
# Processing batch 282 of 1784 batches.
# Processing batch 283 of 1784 batches.
# Processing batch 284 of 1784 batches.
# Processing batch 285 of 1784 batches.
# Processing batch 286 of 1784 batches.
# Processing batch 287 of 1784 batches.
# Processing batch 288 of 1784 batches.
# Processing batch 289 of 1784 batches.
# Processing batch 290 of 1784 batches.
# Processing batch 291 of 1784 batches.
# Processing batch 292 of 1784 batches.
# Processing batch 293 of 1784 batches.
# Processing batch 294 of 1784 batches.
# Processing batch 295 of 1784 batches.
# Processing batch 296 of 1784 batches.
# Processing batch 297 of 1784 batches.
# Processing batch 298 of 1784 batches.
# Processing batch 299 of 1784 batches.
# Processing batch 300 of 1784 batches.
# Processing batch 301 of 1784 batches.
# Processing batch 302 of 1784 batches.
# Processing batch 303 of 1784 batches.
# Processing batch 304 of 1784 batches.
# Processing batch 305 of 1784 batches.
# Processing batch 306 of 1784 batches.
# Processing batch 307 of 1784 batches.
# Processing batch 308 of 1784 batches.
# Processing batch 309 of 1784 batches.
# Processing batch 310 of 1784 batches.
# Processing batch 311 of 1784 batches.
# Processing batch 312 of 1784 batches.
# Processing batch 313 of 1784 batches.
# Processing batch 314 of 1784 batches.
# Processing batch 315 of 1784 batches.
# Processing batch 316 of 1784 batches.
# Processing batch 317 of 1784 batches.
# Processing batch 318 of 1784 batches.
# Processing batch 319 of 1784 batches.
# Processing batch 320 of 1784 batches.
# Processing batch 321 of 1784 batches.
# Processing batch 322 of 1784 batches.
# Processing batch 323 of 1784 batches.
# Processing batch 324 of 1784 batches.
# Processing batch 325 of 1784 batches.
# Processing batch 326 of 1784 batches.
# Processing batch 327 of 1784 batches.
# Processing batch 328 of 1784 batches.
# Processing batch 329 of 1784 batches.
# Processing batch 330 of 1784 batches.
# Processing batch 331 of 1784 batches.
# Processing batch 332 of 1784 batches.
# Processing batch 333 of 1784 batches.
# Processing batch 334 of 1784 batches.
# Processing batch 335 of 1784 batches.
# Processing batch 336 of 1784 batches.
# Processing batch 337 of 1784 batches.
# Processing batch 338 of 1784 batches.
# Processing batch 339 of 1784 batches.
# Processing batch 340 of 1784 batches.
# Processing batch 341 of 1784 batches.
# Processing batch 342 of 1784 batches.
# Processing batch 343 of 1784 batches.
# Processing batch 344 of 1784 batches.
# Processing batch 345 of 1784 batches.
# Processing batch 346 of 1784 batches.
# Processing batch 347 of 1784 batches.
# Processing batch 348 of 1784 batches.
# Processing batch 349 of 1784 batches.
# Processing batch 350 of 1784 batches.
# Processing batch 351 of 1784 batches.
# Processing batch 352 of 1784 batches.
# Processing batch 353 of 1784 batches.
# Processing batch 354 of 1784 batches.
# Processing batch 355 of 1784 batches.
# Processing batch 356 of 1784 batches.
# Processing batch 357 of 1784 batches.
# Processing batch 358 of 1784 batches.
# Processing batch 359 of 1784 batches.
# Processing batch 360 of 1784 batches.
# Processing batch 361 of 1784 batches.
# Processing batch 362 of 1784 batches.
# Processing batch 363 of 1784 batches.
# Processing batch 364 of 1784 batches.
# Processing batch 365 of 1784 batches.
# Processing batch 366 of 1784 batches.
# Processing batch 367 of 1784 batches.
# Processing batch 368 of 1784 batches.
# Processing batch 369 of 1784 batches.
# Processing batch 370 of 1784 batches.
# Processing batch 371 of 1784 batches.
# Processing batch 372 of 1784 batches.
# Processing batch 373 of 1784 batches.
# Processing batch 374 of 1784 batches.
# Processing batch 375 of 1784 batches.
# Processing batch 376 of 1784 batches.
# Processing batch 377 of 1784 batches.
# Processing batch 378 of 1784 batches.
# Processing batch 379 of 1784 batches.
# Processing batch 380 of 1784 batches.
# Processing batch 381 of 1784 batches.
# Processing batch 382 of 1784 batches.
# Processing batch 383 of 1784 batches.
# Processing batch 384 of 1784 batches.
# Processing batch 385 of 1784 batches.
# Processing batch 386 of 1784 batches.
# Processing batch 387 of 1784 batches.
# Processing batch 388 of 1784 batches.
# Processing batch 389 of 1784 batches.
# Processing batch 390 of 1784 batches.
# Processing batch 391 of 1784 batches.
# Processing batch 392 of 1784 batches.
# Processing batch 393 of 1784 batches.
# Processing batch 394 of 1784 batches.
# Processing batch 395 of 1784 batches.
# Processing batch 396 of 1784 batches.
# Processing batch 397 of 1784 batches.
# Processing batch 398 of 1784 batches.
# Processing batch 399 of 1784 batches.
# Processing batch 400 of 1784 batches.
# Processing batch 401 of 1784 batches.
# Processing batch 402 of 1784 batches.
# Processing batch 403 of 1784 batches.
# Processing batch 404 of 1784 batches.
# The LLM made an index error reporting idx= 1
# The LLM made an index error reporting idx= 1
# The LLM made an index error reporting idx= 1
# The LLM made an index error reporting idx= 1
# Processing batch 405 of 1784 batches.
# The LLM made an index error reporting idx= 1
# The LLM made an index error reporting idx= 1
# The LLM made an index error reporting idx= 1
# Processing batch 406 of 1784 batches.
# Processing batch 407 of 1784 batches.
# Processing batch 408 of 1784 batches.
# Processing batch 409 of 1784 batches.
# Processing batch 410 of 1784 batches.
# Processing batch 411 of 1784 batches.
# Processing batch 412 of 1784 batches.
# Processing batch 413 of 1784 batches.
# Processing batch 414 of 1784 batches.
# Processing batch 415 of 1784 batches.
# Processing batch 416 of 1784 batches.
# Processing batch 417 of 1784 batches.
# Processing batch 418 of 1784 batches.
# Processing batch 419 of 1784 batches.
# Processing batch 420 of 1784 batches.
# Processing batch 421 of 1784 batches.
# Processing batch 422 of 1784 batches.
# Processing batch 423 of 1784 batches.
# Processing batch 424 of 1784 batches.
# Processing batch 425 of 1784 batches.
# Processing batch 426 of 1784 batches.
# Processing batch 427 of 1784 batches.
# Processing batch 428 of 1784 batches.
# Processing batch 429 of 1784 batches.
# Processing batch 430 of 1784 batches.
# Processing batch 431 of 1784 batches.
# Processing batch 432 of 1784 batches.
# Processing batch 433 of 1784 batches.
# Processing batch 434 of 1784 batches.
# Processing batch 435 of 1784 batches.
# Processing batch 436 of 1784 batches.
# Processing batch 437 of 1784 batches.
# Processing batch 438 of 1784 batches.
# Processing batch 439 of 1784 batches.
# Processing batch 440 of 1784 batches.
# Processing batch 441 of 1784 batches.
# Processing batch 442 of 1784 batches.
# Processing batch 443 of 1784 batches.
# Processing batch 444 of 1784 batches.
# Processing batch 445 of 1784 batches.
# Processing batch 446 of 1784 batches.
# Processing batch 447 of 1784 batches.
# Processing batch 448 of 1784 batches.
# Processing batch 449 of 1784 batches.
# Processing batch 450 of 1784 batches.
# Processing batch 451 of 1784 batches.
# Processing batch 452 of 1784 batches.
# Processing batch 453 of 1784 batches.
# Processing batch 454 of 1784 batches.
# Processing batch 455 of 1784 batches.
# Processing batch 456 of 1784 batches.
# Processing batch 457 of 1784 batches.
# Processing batch 458 of 1784 batches.
# Processing batch 459 of 1784 batches.
# Processing batch 460 of 1784 batches.
# Processing batch 461 of 1784 batches.
# Processing batch 462 of 1784 batches.
# Processing batch 463 of 1784 batches.
# Processing batch 464 of 1784 batches.
# Processing batch 465 of 1784 batches.
# Processing batch 466 of 1784 batches.
# Processing batch 467 of 1784 batches.
# Processing batch 468 of 1784 batches.
# Processing batch 469 of 1784 batches.
# Processing batch 470 of 1784 batches.
# Processing batch 471 of 1784 batches.
# Processing batch 472 of 1784 batches.
# Processing batch 473 of 1784 batches.
# Processing batch 474 of 1784 batches.
# Processing batch 475 of 1784 batches.
# Processing batch 476 of 1784 batches.
# Processing batch 477 of 1784 batches.
# Processing batch 478 of 1784 batches.
# Processing batch 479 of 1784 batches.
# Processing batch 480 of 1784 batches.
# Processing batch 481 of 1784 batches.
# Must retry when the LLM failed to produce all answers, try= 1
# Processing batch 482 of 1784 batches.
# Processing batch 483 of 1784 batches.
# Processing batch 484 of 1784 batches.
# Processing batch 485 of 1784 batches.
# Processing batch 486 of 1784 batches.
# Processing batch 487 of 1784 batches.
# Processing batch 488 of 1784 batches.
# Processing batch 489 of 1784 batches.
# Processing batch 490 of 1784 batches.
# Processing batch 491 of 1784 batches.
# Processing batch 492 of 1784 batches.
# Processing batch 493 of 1784 batches.
# Processing batch 494 of 1784 batches.
# Processing batch 495 of 1784 batches.
# Processing batch 496 of 1784 batches.
# Processing batch 497 of 1784 batches.
# Processing batch 498 of 1784 batches.
# Processing batch 499 of 1784 batches.
# Processing batch 500 of 1784 batches.
# Processing batch 501 of 1784 batches.
# Processing batch 502 of 1784 batches.
# Processing batch 503 of 1784 batches.
# Processing batch 504 of 1784 batches.
# Processing batch 505 of 1784 batches.
# Processing batch 506 of 1784 batches.
# Processing batch 507 of 1784 batches.
# Processing batch 508 of 1784 batches.
# Processing batch 509 of 1784 batches.
# Processing batch 510 of 1784 batches.
# Processing batch 511 of 1784 batches.
# Processing batch 512 of 1784 batches.
# Processing batch 513 of 1784 batches.
# Processing batch 514 of 1784 batches.
# Processing batch 515 of 1784 batches.
# Processing batch 516 of 1784 batches.
# Processing batch 517 of 1784 batches.
# Processing batch 518 of 1784 batches.
# Processing batch 519 of 1784 batches.
# Processing batch 520 of 1784 batches.
# Processing batch 521 of 1784 batches.
# Processing batch 522 of 1784 batches.
# Processing batch 523 of 1784 batches.
# Processing batch 524 of 1784 batches.
# Processing batch 525 of 1784 batches.
# Processing batch 526 of 1784 batches.
# Processing batch 527 of 1784 batches.
# Processing batch 528 of 1784 batches.
# Processing batch 529 of 1784 batches.
# Processing batch 530 of 1784 batches.
# Processing batch 531 of 1784 batches.
# Processing batch 532 of 1784 batches.
# Processing batch 533 of 1784 batches.
# Processing batch 534 of 1784 batches.
# Processing batch 535 of 1784 batches.
# Processing batch 536 of 1784 batches.
# Processing batch 537 of 1784 batches.
# Processing batch 538 of 1784 batches.
# Processing batch 539 of 1784 batches.
# Processing batch 540 of 1784 batches.
# Processing batch 541 of 1784 batches.
# Processing batch 542 of 1784 batches.
# Processing batch 543 of 1784 batches.
# Processing batch 544 of 1784 batches.
# Processing batch 545 of 1784 batches.
# Processing batch 546 of 1784 batches.
# Processing batch 547 of 1784 batches.
# Processing batch 548 of 1784 batches.
# Processing batch 549 of 1784 batches.
# Processing batch 550 of 1784 batches.
# Processing batch 551 of 1784 batches.
# Processing batch 552 of 1784 batches.
# Processing batch 553 of 1784 batches.
# Processing batch 554 of 1784 batches.
# Processing batch 555 of 1784 batches.
# Processing batch 556 of 1784 batches.
# Processing batch 557 of 1784 batches.
# Processing batch 558 of 1784 batches.
# Processing batch 559 of 1784 batches.
# Processing batch 560 of 1784 batches.
# Processing batch 561 of 1784 batches.
# Processing batch 562 of 1784 batches.
# Processing batch 563 of 1784 batches.
# Processing batch 564 of 1784 batches.
# Processing batch 565 of 1784 batches.
# Processing batch 566 of 1784 batches.
# Processing batch 567 of 1784 batches.
# Processing batch 568 of 1784 batches.
# Processing batch 569 of 1784 batches.
# Processing batch 570 of 1784 batches.
# Processing batch 571 of 1784 batches.
# Processing batch 572 of 1784 batches.
# Processing batch 573 of 1784 batches.
# Processing batch 574 of 1784 batches.
# Processing batch 575 of 1784 batches.
# Processing batch 576 of 1784 batches.
# Processing batch 577 of 1784 batches.
# Processing batch 578 of 1784 batches.
# Processing batch 579 of 1784 batches.
# Processing batch 580 of 1784 batches.
# Processing batch 581 of 1784 batches.
# Processing batch 582 of 1784 batches.
# Processing batch 583 of 1784 batches.
# Processing batch 584 of 1784 batches.
# Processing batch 585 of 1784 batches.
# Processing batch 586 of 1784 batches.
# Processing batch 587 of 1784 batches.
# Processing batch 588 of 1784 batches.
# The LLM made an index error reporting idx= 1
# Processing batch 589 of 1784 batches.
# Processing batch 590 of 1784 batches.
# Processing batch 591 of 1784 batches.
# Processing batch 592 of 1784 batches.
# Processing batch 593 of 1784 batches.
# Processing batch 594 of 1784 batches.
# Processing batch 595 of 1784 batches.
# Processing batch 596 of 1784 batches.
# Processing batch 597 of 1784 batches.
# Processing batch 598 of 1784 batches.
# Processing batch 599 of 1784 batches.
# Processing batch 600 of 1784 batches.
# Processing batch 601 of 1784 batches.
# Processing batch 602 of 1784 batches.
# Processing batch 603 of 1784 batches.
# Processing batch 604 of 1784 batches.
# Processing batch 605 of 1784 batches.
# Processing batch 606 of 1784 batches.
# Processing batch 607 of 1784 batches.
# Processing batch 608 of 1784 batches.
# Processing batch 609 of 1784 batches.
# Processing batch 610 of 1784 batches.
# Processing batch 611 of 1784 batches.
# Processing batch 612 of 1784 batches.
# Processing batch 613 of 1784 batches.
# Processing batch 614 of 1784 batches.
# Processing batch 615 of 1784 batches.
# Processing batch 616 of 1784 batches.
# Processing batch 617 of 1784 batches.
# Processing batch 618 of 1784 batches.
# Processing batch 619 of 1784 batches.
# Processing batch 620 of 1784 batches.
# Processing batch 621 of 1784 batches.
# Processing batch 622 of 1784 batches.
# Processing batch 623 of 1784 batches.
# Processing batch 624 of 1784 batches.
# Processing batch 625 of 1784 batches.
# Processing batch 626 of 1784 batches.
# Processing batch 627 of 1784 batches.
# Processing batch 628 of 1784 batches.
# Processing batch 629 of 1784 batches.
# Processing batch 630 of 1784 batches.
# Processing batch 631 of 1784 batches.
# Processing batch 632 of 1784 batches.
# Processing batch 633 of 1784 batches.
# Processing batch 634 of 1784 batches.
# Processing batch 635 of 1784 batches.
# Processing batch 636 of 1784 batches.
# Processing batch 637 of 1784 batches.
# Processing batch 638 of 1784 batches.
# Processing batch 639 of 1784 batches.
# Processing batch 640 of 1784 batches.
# Processing batch 641 of 1784 batches.
# Processing batch 642 of 1784 batches.
# Processing batch 643 of 1784 batches.
# Processing batch 644 of 1784 batches.
# Processing batch 645 of 1784 batches.
# Processing batch 646 of 1784 batches.
# Processing batch 647 of 1784 batches.
# Processing batch 648 of 1784 batches.
# Processing batch 649 of 1784 batches.
# Processing batch 650 of 1784 batches.
# Processing batch 651 of 1784 batches.
# Processing batch 652 of 1784 batches.
# Processing batch 653 of 1784 batches.
# Processing batch 654 of 1784 batches.
# Processing batch 655 of 1784 batches.
# Processing batch 656 of 1784 batches.
# Processing batch 657 of 1784 batches.
# Processing batch 658 of 1784 batches.
# Processing batch 659 of 1784 batches.
# Processing batch 660 of 1784 batches.
# Processing batch 661 of 1784 batches.
# Processing batch 662 of 1784 batches.
# Processing batch 663 of 1784 batches.
# Processing batch 664 of 1784 batches.
# Processing batch 665 of 1784 batches.
# Processing batch 666 of 1784 batches.
# Processing batch 667 of 1784 batches.
# Processing batch 668 of 1784 batches.
# Processing batch 669 of 1784 batches.
# Processing batch 670 of 1784 batches.
# Processing batch 671 of 1784 batches.
# Processing batch 672 of 1784 batches.
# Processing batch 673 of 1784 batches.
# Processing batch 674 of 1784 batches.
# Processing batch 675 of 1784 batches.
# Processing batch 676 of 1784 batches.
# Processing batch 677 of 1784 batches.
# Processing batch 678 of 1784 batches.
# Processing batch 679 of 1784 batches.
# Processing batch 680 of 1784 batches.
# Processing batch 681 of 1784 batches.
# Processing batch 682 of 1784 batches.
# Processing batch 683 of 1784 batches.
# Processing batch 684 of 1784 batches.
# Processing batch 685 of 1784 batches.
# Processing batch 686 of 1784 batches.
# Processing batch 687 of 1784 batches.
# Processing batch 688 of 1784 batches.
# Processing batch 689 of 1784 batches.
# Processing batch 690 of 1784 batches.
# Processing batch 691 of 1784 batches.
# Processing batch 692 of 1784 batches.
# Processing batch 693 of 1784 batches.
# Processing batch 694 of 1784 batches.
# Processing batch 695 of 1784 batches.
# Processing batch 696 of 1784 batches.
# Processing batch 697 of 1784 batches.
# Processing batch 698 of 1784 batches.
# Processing batch 699 of 1784 batches.
# Processing batch 700 of 1784 batches.
# Processing batch 701 of 1784 batches.
# Processing batch 702 of 1784 batches.
# Processing batch 703 of 1784 batches.
# Processing batch 704 of 1784 batches.
# Processing batch 705 of 1784 batches.
# Processing batch 706 of 1784 batches.
# Processing batch 707 of 1784 batches.
# Processing batch 708 of 1784 batches.
# Processing batch 709 of 1784 batches.
# Processing batch 710 of 1784 batches.
# Processing batch 711 of 1784 batches.
# Processing batch 712 of 1784 batches.
# Processing batch 713 of 1784 batches.
# Processing batch 714 of 1784 batches.
# Processing batch 715 of 1784 batches.
# Processing batch 716 of 1784 batches.
# Processing batch 717 of 1784 batches.
# Processing batch 718 of 1784 batches.
# Processing batch 719 of 1784 batches.
# Processing batch 720 of 1784 batches.
# Processing batch 721 of 1784 batches.
# Processing batch 722 of 1784 batches.
# Processing batch 723 of 1784 batches.
# Processing batch 724 of 1784 batches.
# Processing batch 725 of 1784 batches.
# Processing batch 726 of 1784 batches.
# Processing batch 727 of 1784 batches.
# Processing batch 728 of 1784 batches.
# Processing batch 729 of 1784 batches.
# Processing batch 730 of 1784 batches.
# Processing batch 731 of 1784 batches.
# Processing batch 732 of 1784 batches.
# Processing batch 733 of 1784 batches.
# Processing batch 734 of 1784 batches.
# Processing batch 735 of 1784 batches.
# Processing batch 736 of 1784 batches.
# Processing batch 737 of 1784 batches.
# Processing batch 738 of 1784 batches.
# Processing batch 739 of 1784 batches.
# Processing batch 740 of 1784 batches.
# Processing batch 741 of 1784 batches.
# Processing batch 742 of 1784 batches.
# Processing batch 743 of 1784 batches.
# Processing batch 744 of 1784 batches.
# Processing batch 745 of 1784 batches.
# Processing batch 746 of 1784 batches.
# Processing batch 747 of 1784 batches.
# Processing batch 748 of 1784 batches.
# Processing batch 749 of 1784 batches.
# Processing batch 750 of 1784 batches.
# Processing batch 751 of 1784 batches.
# Processing batch 752 of 1784 batches.
# Processing batch 753 of 1784 batches.
# Processing batch 754 of 1784 batches.
# Processing batch 755 of 1784 batches.
# Processing batch 756 of 1784 batches.
# Processing batch 757 of 1784 batches.
# Processing batch 758 of 1784 batches.
# Processing batch 759 of 1784 batches.
# Processing batch 760 of 1784 batches.
# Processing batch 761 of 1784 batches.
# Processing batch 762 of 1784 batches.
# Processing batch 763 of 1784 batches.
# Processing batch 764 of 1784 batches.
# Processing batch 765 of 1784 batches.
# Processing batch 766 of 1784 batches.
# Processing batch 767 of 1784 batches.
# Processing batch 768 of 1784 batches.
# Processing batch 769 of 1784 batches.
# Processing batch 770 of 1784 batches.
# Processing batch 771 of 1784 batches.
# Processing batch 772 of 1784 batches.
# Processing batch 773 of 1784 batches.
# Processing batch 774 of 1784 batches.
# Processing batch 775 of 1784 batches.
# Processing batch 776 of 1784 batches.
# Processing batch 777 of 1784 batches.
# Processing batch 778 of 1784 batches.
# Processing batch 779 of 1784 batches.
# Processing batch 780 of 1784 batches.
# Processing batch 781 of 1784 batches.
# Processing batch 782 of 1784 batches.
# Processing batch 783 of 1784 batches.
# Processing batch 784 of 1784 batches.
# Processing batch 785 of 1784 batches.
# Processing batch 786 of 1784 batches.
# Processing batch 787 of 1784 batches.
# Processing batch 788 of 1784 batches.
# Processing batch 789 of 1784 batches.
# Processing batch 790 of 1784 batches.
# Processing batch 791 of 1784 batches.
# Processing batch 792 of 1784 batches.
# Processing batch 793 of 1784 batches.
# Processing batch 794 of 1784 batches.
# Processing batch 795 of 1784 batches.
# Processing batch 796 of 1784 batches.
# Processing batch 797 of 1784 batches.
# Processing batch 798 of 1784 batches.
# Processing batch 799 of 1784 batches.
# Processing batch 800 of 1784 batches.
# Processing batch 801 of 1784 batches.
# Processing batch 802 of 1784 batches.
# Processing batch 803 of 1784 batches.
# Processing batch 804 of 1784 batches.
# Processing batch 805 of 1784 batches.
# Processing batch 806 of 1784 batches.
# Processing batch 807 of 1784 batches.
# Processing batch 808 of 1784 batches.
# Processing batch 809 of 1784 batches.
# Processing batch 810 of 1784 batches.
# Processing batch 811 of 1784 batches.
# Processing batch 812 of 1784 batches.
# Processing batch 813 of 1784 batches.
# Processing batch 814 of 1784 batches.
# Processing batch 815 of 1784 batches.
# Processing batch 816 of 1784 batches.
# Processing batch 817 of 1784 batches.
# Processing batch 818 of 1784 batches.
# Processing batch 819 of 1784 batches.
# Processing batch 820 of 1784 batches.
# Processing batch 821 of 1784 batches.
# Processing batch 822 of 1784 batches.
# Processing batch 823 of 1784 batches.
# Processing batch 824 of 1784 batches.
# Processing batch 825 of 1784 batches.
# Processing batch 826 of 1784 batches.
# Processing batch 827 of 1784 batches.
# Processing batch 828 of 1784 batches.
# Processing batch 829 of 1784 batches.
# Processing batch 830 of 1784 batches.
# Processing batch 831 of 1784 batches.
# Processing batch 832 of 1784 batches.
# Processing batch 833 of 1784 batches.
# Processing batch 834 of 1784 batches.
# Processing batch 835 of 1784 batches.
# Processing batch 836 of 1784 batches.
# Processing batch 837 of 1784 batches.
# Processing batch 838 of 1784 batches.
# Processing batch 839 of 1784 batches.
# Processing batch 840 of 1784 batches.
# Processing batch 841 of 1784 batches.
# Processing batch 842 of 1784 batches.
# Processing batch 843 of 1784 batches.
# Processing batch 844 of 1784 batches.
# Processing batch 845 of 1784 batches.
# Processing batch 846 of 1784 batches.
# Processing batch 847 of 1784 batches.
# Processing batch 848 of 1784 batches.
# Processing batch 849 of 1784 batches.
# Processing batch 850 of 1784 batches.
# Processing batch 851 of 1784 batches.
# Processing batch 852 of 1784 batches.
# Processing batch 853 of 1784 batches.
# Processing batch 854 of 1784 batches.
# Processing batch 855 of 1784 batches.
# Processing batch 856 of 1784 batches.
# Processing batch 857 of 1784 batches.
# Processing batch 858 of 1784 batches.
# Processing batch 859 of 1784 batches.
# Processing batch 860 of 1784 batches.
# Processing batch 861 of 1784 batches.
# Processing batch 862 of 1784 batches.
# Processing batch 863 of 1784 batches.
# Processing batch 864 of 1784 batches.
# Processing batch 865 of 1784 batches.
# Processing batch 866 of 1784 batches.
# Processing batch 867 of 1784 batches.
# Processing batch 868 of 1784 batches.
# Processing batch 869 of 1784 batches.
# Processing batch 870 of 1784 batches.
# Processing batch 871 of 1784 batches.
# Processing batch 872 of 1784 batches.
# Processing batch 873 of 1784 batches.
# Processing batch 874 of 1784 batches.
# Processing batch 875 of 1784 batches.
# Processing batch 876 of 1784 batches.
# Processing batch 877 of 1784 batches.
# Processing batch 878 of 1784 batches.
# Processing batch 879 of 1784 batches.
# Processing batch 880 of 1784 batches.
# Processing batch 881 of 1784 batches.
# Processing batch 882 of 1784 batches.
# Processing batch 883 of 1784 batches.
# Processing batch 884 of 1784 batches.
# Processing batch 885 of 1784 batches.
# Processing batch 886 of 1784 batches.
# Processing batch 887 of 1784 batches.
# Processing batch 888 of 1784 batches.
# Processing batch 889 of 1784 batches.
# Processing batch 890 of 1784 batches.
# Processing batch 891 of 1784 batches.
# Processing batch 892 of 1784 batches.
# Processing batch 893 of 1784 batches.
# Processing batch 894 of 1784 batches.
# Processing batch 895 of 1784 batches.
# Processing batch 896 of 1784 batches.
# Processing batch 897 of 1784 batches.
# Processing batch 898 of 1784 batches.
# Processing batch 899 of 1784 batches.
# Processing batch 900 of 1784 batches.
# Processing batch 901 of 1784 batches.
# Processing batch 902 of 1784 batches.
# Processing batch 903 of 1784 batches.
# Processing batch 904 of 1784 batches.
# Processing batch 905 of 1784 batches.
# Processing batch 906 of 1784 batches.
# Processing batch 907 of 1784 batches.
# Processing batch 908 of 1784 batches.
# Processing batch 909 of 1784 batches.
# Processing batch 910 of 1784 batches.
# Processing batch 911 of 1784 batches.
# Processing batch 912 of 1784 batches.
# Processing batch 913 of 1784 batches.
# Processing batch 914 of 1784 batches.
# Processing batch 915 of 1784 batches.
# Processing batch 916 of 1784 batches.
# Processing batch 917 of 1784 batches.
# Processing batch 918 of 1784 batches.
# Processing batch 919 of 1784 batches.
# Processing batch 920 of 1784 batches.
# Processing batch 921 of 1784 batches.
# Processing batch 922 of 1784 batches.
# Processing batch 923 of 1784 batches.
# Processing batch 924 of 1784 batches.
# Processing batch 925 of 1784 batches.
# Processing batch 926 of 1784 batches.
# Processing batch 927 of 1784 batches.
# Processing batch 928 of 1784 batches.
# Processing batch 929 of 1784 batches.
# Processing batch 930 of 1784 batches.
# Processing batch 931 of 1784 batches.
# Processing batch 932 of 1784 batches.
# Processing batch 933 of 1784 batches.
# Processing batch 934 of 1784 batches.
# Processing batch 935 of 1784 batches.
# Processing batch 936 of 1784 batches.
# Processing batch 937 of 1784 batches.
# Processing batch 938 of 1784 batches.
# Processing batch 939 of 1784 batches.
# Processing batch 940 of 1784 batches.
# Processing batch 941 of 1784 batches.
# Processing batch 942 of 1784 batches.
# Processing batch 943 of 1784 batches.
# Processing batch 944 of 1784 batches.
# Processing batch 945 of 1784 batches.
# Processing batch 946 of 1784 batches.
# Processing batch 947 of 1784 batches.
# Processing batch 948 of 1784 batches.
# Processing batch 949 of 1784 batches.
# Processing batch 950 of 1784 batches.
# Processing batch 951 of 1784 batches.
# Processing batch 952 of 1784 batches.
# Processing batch 953 of 1784 batches.
# Processing batch 954 of 1784 batches.
# Processing batch 955 of 1784 batches.
# Processing batch 956 of 1784 batches.
# Processing batch 957 of 1784 batches.
# Processing batch 958 of 1784 batches.
# Processing batch 959 of 1784 batches.
# Processing batch 960 of 1784 batches.
# Processing batch 961 of 1784 batches.
# Processing batch 962 of 1784 batches.
# Processing batch 963 of 1784 batches.
# Processing batch 964 of 1784 batches.
# Processing batch 965 of 1784 batches.
# Processing batch 966 of 1784 batches.
# Processing batch 967 of 1784 batches.
# Processing batch 968 of 1784 batches.
# Processing batch 969 of 1784 batches.
# Processing batch 970 of 1784 batches.
# Processing batch 971 of 1784 batches.
# Processing batch 972 of 1784 batches.
# Processing batch 973 of 1784 batches.
# Processing batch 974 of 1784 batches.
# Processing batch 975 of 1784 batches.
# Processing batch 976 of 1784 batches.
# Processing batch 977 of 1784 batches.
# Processing batch 978 of 1784 batches.
# Processing batch 979 of 1784 batches.
# Processing batch 980 of 1784 batches.
# Processing batch 981 of 1784 batches.
# Processing batch 982 of 1784 batches.
# Processing batch 983 of 1784 batches.
# Processing batch 984 of 1784 batches.
# Processing batch 985 of 1784 batches.
# Processing batch 986 of 1784 batches.
# Processing batch 987 of 1784 batches.
# Processing batch 988 of 1784 batches.
# Processing batch 989 of 1784 batches.
# Processing batch 990 of 1784 batches.
# Must retry when the LLM failed to produce all answers, try= 1
# Processing batch 991 of 1784 batches.
# Processing batch 992 of 1784 batches.
# Processing batch 993 of 1784 batches.
# Processing batch 994 of 1784 batches.
# Processing batch 995 of 1784 batches.
# Processing batch 996 of 1784 batches.
# Processing batch 997 of 1784 batches.
# Processing batch 998 of 1784 batches.
# Processing batch 999 of 1784 batches.
# Processing batch 1000 of 1784 batches.
# Processing batch 1001 of 1784 batches.
# Processing batch 1002 of 1784 batches.
# Processing batch 1003 of 1784 batches.
# Processing batch 1004 of 1784 batches.
# Processing batch 1005 of 1784 batches.
# Processing batch 1006 of 1784 batches.
# Processing batch 1007 of 1784 batches.
# Processing batch 1008 of 1784 batches.
# Processing batch 1009 of 1784 batches.
# Processing batch 1010 of 1784 batches.
# Processing batch 1011 of 1784 batches.
# Processing batch 1012 of 1784 batches.
# Processing batch 1013 of 1784 batches.
# Processing batch 1014 of 1784 batches.
# Processing batch 1015 of 1784 batches.
# Processing batch 1016 of 1784 batches.
# Processing batch 1017 of 1784 batches.
# Processing batch 1018 of 1784 batches.
# Processing batch 1019 of 1784 batches.
# Processing batch 1020 of 1784 batches.
# Processing batch 1021 of 1784 batches.
# Processing batch 1022 of 1784 batches.
# Processing batch 1023 of 1784 batches.
# Processing batch 1024 of 1784 batches.
# Processing batch 1025 of 1784 batches.
# Processing batch 1026 of 1784 batches.
# Processing batch 1027 of 1784 batches.
# Processing batch 1028 of 1784 batches.
# Processing batch 1029 of 1784 batches.
# Processing batch 1030 of 1784 batches.
# Processing batch 1031 of 1784 batches.
# Processing batch 1032 of 1784 batches.
# Processing batch 1033 of 1784 batches.
# Processing batch 1034 of 1784 batches.
# Processing batch 1035 of 1784 batches.
# Processing batch 1036 of 1784 batches.
# Processing batch 1037 of 1784 batches.
# Processing batch 1038 of 1784 batches.
# Processing batch 1039 of 1784 batches.
# Processing batch 1040 of 1784 batches.
# Processing batch 1041 of 1784 batches.
# Processing batch 1042 of 1784 batches.
# Processing batch 1043 of 1784 batches.
# Processing batch 1044 of 1784 batches.
# Processing batch 1045 of 1784 batches.
# Processing batch 1046 of 1784 batches.
# Processing batch 1047 of 1784 batches.
# Processing batch 1048 of 1784 batches.
# Processing batch 1049 of 1784 batches.
# Processing batch 1050 of 1784 batches.
# Processing batch 1051 of 1784 batches.
# Processing batch 1052 of 1784 batches.
# Processing batch 1053 of 1784 batches.
# Processing batch 1054 of 1784 batches.
# Processing batch 1055 of 1784 batches.
# Processing batch 1056 of 1784 batches.
# Processing batch 1057 of 1784 batches.
# Processing batch 1058 of 1784 batches.
# Processing batch 1059 of 1784 batches.
# Processing batch 1060 of 1784 batches.
# Processing batch 1061 of 1784 batches.
# Processing batch 1062 of 1784 batches.
# Processing batch 1063 of 1784 batches.
# Processing batch 1064 of 1784 batches.
# Processing batch 1065 of 1784 batches.
# Processing batch 1066 of 1784 batches.
# Processing batch 1067 of 1784 batches.
# Processing batch 1068 of 1784 batches.
# Processing batch 1069 of 1784 batches.
# Processing batch 1070 of 1784 batches.
# Processing batch 1071 of 1784 batches.
# Processing batch 1072 of 1784 batches.
# Processing batch 1073 of 1784 batches.
# Processing batch 1074 of 1784 batches.
# Processing batch 1075 of 1784 batches.
# Processing batch 1076 of 1784 batches.
# Processing batch 1077 of 1784 batches.
# Processing batch 1078 of 1784 batches.
# Processing batch 1079 of 1784 batches.
# Processing batch 1080 of 1784 batches.
# Processing batch 1081 of 1784 batches.
# Processing batch 1082 of 1784 batches.
# Processing batch 1083 of 1784 batches.
# Processing batch 1084 of 1784 batches.
# Processing batch 1085 of 1784 batches.
# Processing batch 1086 of 1784 batches.
# Processing batch 1087 of 1784 batches.
# Processing batch 1088 of 1784 batches.
# Processing batch 1089 of 1784 batches.
# Processing batch 1090 of 1784 batches.
# Processing batch 1091 of 1784 batches.
# Processing batch 1092 of 1784 batches.
# Processing batch 1093 of 1784 batches.
# Processing batch 1094 of 1784 batches.
# Processing batch 1095 of 1784 batches.
# Processing batch 1096 of 1784 batches.
# Processing batch 1097 of 1784 batches.
# Processing batch 1098 of 1784 batches.
# Processing batch 1099 of 1784 batches.
# Processing batch 1100 of 1784 batches.
# Processing batch 1101 of 1784 batches.
# Processing batch 1102 of 1784 batches.
# Processing batch 1103 of 1784 batches.
# Processing batch 1104 of 1784 batches.
# Processing batch 1105 of 1784 batches.
# Processing batch 1106 of 1784 batches.
# Processing batch 1107 of 1784 batches.
# Processing batch 1108 of 1784 batches.
# Processing batch 1109 of 1784 batches.
# Processing batch 1110 of 1784 batches.
# Processing batch 1111 of 1784 batches.
# Processing batch 1112 of 1784 batches.
# Processing batch 1113 of 1784 batches.
# Processing batch 1114 of 1784 batches.
# Processing batch 1115 of 1784 batches.
# Processing batch 1116 of 1784 batches.
# Processing batch 1117 of 1784 batches.
# Processing batch 1118 of 1784 batches.
# Processing batch 1119 of 1784 batches.
# Processing batch 1120 of 1784 batches.
# Processing batch 1121 of 1784 batches.
# Processing batch 1122 of 1784 batches.
# Processing batch 1123 of 1784 batches.
# Processing batch 1124 of 1784 batches.
# Processing batch 1125 of 1784 batches.
# Processing batch 1126 of 1784 batches.
# Processing batch 1127 of 1784 batches.
# Processing batch 1128 of 1784 batches.
# Processing batch 1129 of 1784 batches.
# Processing batch 1130 of 1784 batches.
# Processing batch 1131 of 1784 batches.
# Processing batch 1132 of 1784 batches.
# Processing batch 1133 of 1784 batches.
# Processing batch 1134 of 1784 batches.
# Processing batch 1135 of 1784 batches.
# Processing batch 1136 of 1784 batches.
# Processing batch 1137 of 1784 batches.
# Processing batch 1138 of 1784 batches.
# Processing batch 1139 of 1784 batches.
# Processing batch 1140 of 1784 batches.
# Processing batch 1141 of 1784 batches.
# Processing batch 1142 of 1784 batches.
# Processing batch 1143 of 1784 batches.
# Processing batch 1144 of 1784 batches.
# Processing batch 1145 of 1784 batches.
# Processing batch 1146 of 1784 batches.
# Processing batch 1147 of 1784 batches.
# Processing batch 1148 of 1784 batches.
# Processing batch 1149 of 1784 batches.
# Processing batch 1150 of 1784 batches.
# Processing batch 1151 of 1784 batches.
# Processing batch 1152 of 1784 batches.
# Processing batch 1153 of 1784 batches.
# Processing batch 1154 of 1784 batches.
# Processing batch 1155 of 1784 batches.
# Processing batch 1156 of 1784 batches.
# Processing batch 1157 of 1784 batches.
# Processing batch 1158 of 1784 batches.
# Processing batch 1159 of 1784 batches.
# Processing batch 1160 of 1784 batches.
# Processing batch 1161 of 1784 batches.
# Processing batch 1162 of 1784 batches.
# Processing batch 1163 of 1784 batches.
# Processing batch 1164 of 1784 batches.
# Processing batch 1165 of 1784 batches.
# Processing batch 1166 of 1784 batches.
# Processing batch 1167 of 1784 batches.
# Processing batch 1168 of 1784 batches.
# Processing batch 1169 of 1784 batches.
# Processing batch 1170 of 1784 batches.
# Processing batch 1171 of 1784 batches.
# Processing batch 1172 of 1784 batches.
# Processing batch 1173 of 1784 batches.
# Processing batch 1174 of 1784 batches.
# Processing batch 1175 of 1784 batches.
# Processing batch 1176 of 1784 batches.
# Processing batch 1177 of 1784 batches.
# Processing batch 1178 of 1784 batches.
# Processing batch 1179 of 1784 batches.
# Processing batch 1180 of 1784 batches.
# Processing batch 1181 of 1784 batches.
# Processing batch 1182 of 1784 batches.
# Processing batch 1183 of 1784 batches.
# Processing batch 1184 of 1784 batches.
# Processing batch 1185 of 1784 batches.
# Processing batch 1186 of 1784 batches.
# Processing batch 1187 of 1784 batches.
# Processing batch 1188 of 1784 batches.
# Processing batch 1189 of 1784 batches.
# Processing batch 1190 of 1784 batches.
# Processing batch 1191 of 1784 batches.
# Processing batch 1192 of 1784 batches.
# Processing batch 1193 of 1784 batches.
# Processing batch 1194 of 1784 batches.
# Processing batch 1195 of 1784 batches.
# Processing batch 1196 of 1784 batches.
# Processing batch 1197 of 1784 batches.
# Processing batch 1198 of 1784 batches.
# Processing batch 1199 of 1784 batches.
# Processing batch 1200 of 1784 batches.
# Processing batch 1201 of 1784 batches.
# Processing batch 1202 of 1784 batches.
# Processing batch 1203 of 1784 batches.
# Processing batch 1204 of 1784 batches.
# Processing batch 1205 of 1784 batches.
# Processing batch 1206 of 1784 batches.
# Processing batch 1207 of 1784 batches.
# Processing batch 1208 of 1784 batches.
# Processing batch 1209 of 1784 batches.
# Processing batch 1210 of 1784 batches.
# Processing batch 1211 of 1784 batches.
# Processing batch 1212 of 1784 batches.
# Processing batch 1213 of 1784 batches.
# Processing batch 1214 of 1784 batches.
# Processing batch 1215 of 1784 batches.
# Processing batch 1216 of 1784 batches.
# Processing batch 1217 of 1784 batches.
# Processing batch 1218 of 1784 batches.
# Processing batch 1219 of 1784 batches.
# Processing batch 1220 of 1784 batches.
# Processing batch 1221 of 1784 batches.
# Processing batch 1222 of 1784 batches.
# Processing batch 1223 of 1784 batches.
# Processing batch 1224 of 1784 batches.
# Processing batch 1225 of 1784 batches.
# Processing batch 1226 of 1784 batches.
# Processing batch 1227 of 1784 batches.
# Processing batch 1228 of 1784 batches.
# Processing batch 1229 of 1784 batches.
# Processing batch 1230 of 1784 batches.
# Processing batch 1231 of 1784 batches.
# Processing batch 1232 of 1784 batches.
# Processing batch 1233 of 1784 batches.
# Processing batch 1234 of 1784 batches.
# Processing batch 1235 of 1784 batches.
# Processing batch 1236 of 1784 batches.
# Processing batch 1237 of 1784 batches.
# Processing batch 1238 of 1784 batches.
# Processing batch 1239 of 1784 batches.
# Processing batch 1240 of 1784 batches.
# Processing batch 1241 of 1784 batches.
# Processing batch 1242 of 1784 batches.
# Processing batch 1243 of 1784 batches.
# Processing batch 1244 of 1784 batches.
# Processing batch 1245 of 1784 batches.
# Processing batch 1246 of 1784 batches.
# ...
# Processing batch 1377 of 1784 batches.
# Processing batch 1378 of 1784 batches.
# Processing batch 1379 of 1784 batches.
# Processing batch 1380 of 1784 batches.
# Processing batch 1381 of 1784 batches.
# Processing batch 1382 of 1784 batches.
# Processing batch 1383 of 1784 batches.
# Processing batch 1384 of 1784 batches.
# Processing batch 1385 of 1784 batches.
# Processing batch 1386 of 1784 batches.
# Processing batch 1387 of 1784 batches.
# Processing batch 1388 of 1784 batches.
# Processing batch 1389 of 1784 batches.
# Processing batch 1390 of 1784 batches.
# Processing batch 1391 of 1784 batches.
# Processing batch 1392 of 1784 batches.
# Processing batch 1393 of 1784 batches.
# Processing batch 1394 of 1784 batches.
# Processing batch 1395 of 1784 batches.
# Processing batch 1396 of 1784 batches.
# Processing batch 1397 of 1784 batches.
# Processing batch 1398 of 1784 batches.
# Processing batch 1399 of 1784 batches.
# Processing batch 1400 of 1784 batches.
# Processing batch 1401 of 1784 batches.
# Processing batch 1402 of 1784 batches.
# Processing batch 1403 of 1784 batches.
# Processing batch 1404 of 1784 batches.
# Processing batch 1405 of 1784 batches.
# Processing batch 1406 of 1784 batches.
# Processing batch 1407 of 1784 batches.
# Processing batch 1408 of 1784 batches.
# Processing batch 1409 of 1784 batches.
# Processing batch 1410 of 1784 batches.
# Processing batch 1411 of 1784 batches.
# Processing batch 1412 of 1784 batches.
# Processing batch 1413 of 1784 batches.
# Processing batch 1414 of 1784 batches.
# Processing batch 1415 of 1784 batches.
# Processing batch 1416 of 1784 batches.
# Processing batch 1417 of 1784 batches.
# Processing batch 1418 of 1784 batches.
# Processing batch 1419 of 1784 batches.
# Processing batch 1420 of 1784 batches.
# Processing batch 1421 of 1784 batches.
# Processing batch 1422 of 1784 batches.
# Processing batch 1423 of 1784 batches.
# Processing batch 1424 of 1784 batches.
# Processing batch 1425 of 1784 batches.
# Processing batch 1426 of 1784 batches.
# Processing batch 1427 of 1784 batches.
# Processing batch 1428 of 1784 batches.
# Processing batch 1429 of 1784 batches.
# Processing batch 1430 of 1784 batches.
# Processing batch 1431 of 1784 batches.
# Processing batch 1432 of 1784 batches.
# Processing batch 1433 of 1784 batches.
# Processing batch 1434 of 1784 batches.
# Processing batch 1435 of 1784 batches.
# Processing batch 1436 of 1784 batches.
# Processing batch 1437 of 1784 batches.
# Processing batch 1438 of 1784 batches.
# Processing batch 1439 of 1784 batches.
# Processing batch 1440 of 1784 batches.
# Processing batch 1441 of 1784 batches.
# Processing batch 1442 of 1784 batches.
# Processing batch 1443 of 1784 batches.
# Processing batch 1444 of 1784 batches.
# Processing batch 1445 of 1784 batches.
# Processing batch 1446 of 1784 batches.
# Processing batch 1447 of 1784 batches.
# Processing batch 1448 of 1784 batches.
# Processing batch 1449 of 1784 batches.
# Processing batch 1450 of 1784 batches.
# Processing batch 1451 of 1784 batches.
# Processing batch 1452 of 1784 batches.
# Processing batch 1453 of 1784 batches.
# Processing batch 1454 of 1784 batches.
# Processing batch 1455 of 1784 batches.
# Processing batch 1456 of 1784 batches.
# Processing batch 1457 of 1784 batches.
# Processing batch 1458 of 1784 batches.
# Processing batch 1459 of 1784 batches.
# Processing batch 1460 of 1784 batches.
# Processing batch 1461 of 1784 batches.
# Processing batch 1462 of 1784 batches.
# Processing batch 1463 of 1784 batches.
# Processing batch 1464 of 1784 batches.
# Processing batch 1465 of 1784 batches.
# Processing batch 1466 of 1784 batches.
# Processing batch 1467 of 1784 batches.
# Processing batch 1468 of 1784 batches.
# Processing batch 1469 of 1784 batches.
# Processing batch 1470 of 1784 batches.
# Processing batch 1471 of 1784 batches.
# Processing batch 1472 of 1784 batches.
# Processing batch 1473 of 1784 batches.
# Processing batch 1474 of 1784 batches.
# Processing batch 1475 of 1784 batches.
# Processing batch 1476 of 1784 batches.
# Processing batch 1477 of 1784 batches.
# Processing batch 1478 of 1784 batches.
# Processing batch 1479 of 1784 batches.
# Processing batch 1480 of 1784 batches.
# Processing batch 1481 of 1784 batches.
# Processing batch 1482 of 1784 batches.
# Processing batch 1483 of 1784 batches.
# Processing batch 1484 of 1784 batches.
# Processing batch 1485 of 1784 batches.
# Processing batch 1486 of 1784 batches.
# Processing batch 1487 of 1784 batches.
# Processing batch 1488 of 1784 batches.
# Processing batch 1489 of 1784 batches.
# Processing batch 1490 of 1784 batches.
# Processing batch 1491 of 1784 batches.
# Processing batch 1492 of 1784 batches.
# Processing batch 1493 of 1784 batches.
# Processing batch 1494 of 1784 batches.
# Processing batch 1495 of 1784 batches.
# Processing batch 1496 of 1784 batches.
# Processing batch 1497 of 1784 batches.
# Processing batch 1498 of 1784 batches.
# Processing batch 1499 of 1784 batches.
# Processing batch 1500 of 1784 batches.
# Processing batch 1501 of 1784 batches.
# Processing batch 1502 of 1784 batches.
# Processing batch 1503 of 1784 batches.
# Processing batch 1504 of 1784 batches.
# Processing batch 1505 of 1784 batches.
# Processing batch 1506 of 1784 batches.
# Processing batch 1507 of 1784 batches.
# Processing batch 1508 of 1784 batches.
# Processing batch 1509 of 1784 batches.
# Processing batch 1510 of 1784 batches.
# Processing batch 1511 of 1784 batches.
# Processing batch 1512 of 1784 batches.
# Processing batch 1513 of 1784 batches.
# Processing batch 1514 of 1784 batches.
# Processing batch 1515 of 1784 batches.
# Processing batch 1516 of 1784 batches.
# Processing batch 1517 of 1784 batches.
# Processing batch 1518 of 1784 batches.
# Processing batch 1519 of 1784 batches.
# Processing batch 1520 of 1784 batches.
# Processing batch 1521 of 1784 batches.
# Processing batch 1522 of 1784 batches.
# Processing batch 1523 of 1784 batches.
# Processing batch 1524 of 1784 batches.
# Processing batch 1525 of 1784 batches.
# Processing batch 1526 of 1784 batches.
# Processing batch 1527 of 1784 batches.
# Processing batch 1528 of 1784 batches.
# Processing batch 1529 of 1784 batches.
# Processing batch 1530 of 1784 batches.
# Processing batch 1531 of 1784 batches.
# Processing batch 1532 of 1784 batches.
# Processing batch 1533 of 1784 batches.
# Processing batch 1534 of 1784 batches.
# Processing batch 1535 of 1784 batches.
# Processing batch 1536 of 1784 batches.
# Processing batch 1537 of 1784 batches.
# Processing batch 1538 of 1784 batches.
# Processing batch 1539 of 1784 batches.
# Processing batch 1540 of 1784 batches.
# Processing batch 1541 of 1784 batches.
# Processing batch 1542 of 1784 batches.
# Processing batch 1543 of 1784 batches.
# Processing batch 1544 of 1784 batches.
# Processing batch 1545 of 1784 batches.
# Processing batch 1546 of 1784 batches.
# Processing batch 1547 of 1784 batches.
# Processing batch 1548 of 1784 batches.
# Processing batch 1549 of 1784 batches.
# Processing batch 1550 of 1784 batches.
# Processing batch 1551 of 1784 batches.
# Processing batch 1552 of 1784 batches.
# Processing batch 1553 of 1784 batches.
# Processing batch 1554 of 1784 batches.
# Processing batch 1555 of 1784 batches.
# Processing batch 1556 of 1784 batches.
# Processing batch 1557 of 1784 batches.
# Processing batch 1558 of 1784 batches.
# Processing batch 1559 of 1784 batches.
# Processing batch 1560 of 1784 batches.
# Processing batch 1561 of 1784 batches.
# Processing batch 1562 of 1784 batches.
# Processing batch 1563 of 1784 batches.
# Processing batch 1564 of 1784 batches.
# Processing batch 1565 of 1784 batches.
# Processing batch 1566 of 1784 batches.
# Processing batch 1567 of 1784 batches.
# Processing batch 1568 of 1784 batches.
# Processing batch 1569 of 1784 batches.
# Processing batch 1570 of 1784 batches.
# Processing batch 1571 of 1784 batches.
# Processing batch 1572 of 1784 batches.
# Processing batch 1573 of 1784 batches.
# Processing batch 1574 of 1784 batches.
# Processing batch 1575 of 1784 batches.
# Processing batch 1576 of 1784 batches.
# Processing batch 1577 of 1784 batches.
# Processing batch 1578 of 1784 batches.
# Processing batch 1579 of 1784 batches.
# Processing batch 1580 of 1784 batches.
# Processing batch 1581 of 1784 batches.
# Processing batch 1582 of 1784 batches.
# Processing batch 1583 of 1784 batches.
# Processing batch 1584 of 1784 batches.
# Processing batch 1585 of 1784 batches.
# Processing batch 1586 of 1784 batches.
# Processing batch 1587 of 1784 batches.
# Processing batch 1588 of 1784 batches.
# Processing batch 1589 of 1784 batches.
# Processing batch 1590 of 1784 batches.
# Processing batch 1591 of 1784 batches.
# Processing batch 1592 of 1784 batches.
# Processing batch 1593 of 1784 batches.
# Processing batch 1594 of 1784 batches.
# Processing batch 1595 of 1784 batches.
# Processing batch 1596 of 1784 batches.
# Processing batch 1597 of 1784 batches.
# Processing batch 1598 of 1784 batches.
# Must retry when the LLM failed to produce all answers, try= 1
# Processing batch 1599 of 1784 batches.
# Processing batch 1600 of 1784 batches.
# Processing batch 1601 of 1784 batches.
# Processing batch 1602 of 1784 batches.
# Processing batch 1603 of 1784 batches.
# Processing batch 1604 of 1784 batches.
# Processing batch 1605 of 1784 batches.
# Processing batch 1606 of 1784 batches.
# Processing batch 1607 of 1784 batches.
# Processing batch 1608 of 1784 batches.
# Processing batch 1609 of 1784 batches.
# Processing batch 1610 of 1784 batches.
# Processing batch 1611 of 1784 batches.
# Processing batch 1612 of 1784 batches.
# Processing batch 1613 of 1784 batches.
# Processing batch 1614 of 1784 batches.
# Processing batch 1615 of 1784 batches.
# Processing batch 1616 of 1784 batches.
# Processing batch 1617 of 1784 batches.
# Processing batch 1618 of 1784 batches.
# Processing batch 1619 of 1784 batches.
# Processing batch 1620 of 1784 batches.
# Processing batch 1621 of 1784 batches.
# Processing batch 1622 of 1784 batches.
# Processing batch 1623 of 1784 batches.
# Processing batch 1624 of 1784 batches.
# Processing batch 1625 of 1784 batches.
# Processing batch 1626 of 1784 batches.
# Processing batch 1627 of 1784 batches.
# Processing batch 1628 of 1784 batches.
# Processing batch 1629 of 1784 batches.
# Processing batch 1630 of 1784 batches.
# Processing batch 1631 of 1784 batches.
# Processing batch 1632 of 1784 batches.
# Processing batch 1633 of 1784 batches.
# Processing batch 1634 of 1784 batches.
# Processing batch 1635 of 1784 batches.
# Processing batch 1636 of 1784 batches.
# Processing batch 1637 of 1784 batches.
# Processing batch 1638 of 1784 batches.
# Processing batch 1639 of 1784 batches.
# Processing batch 1640 of 1784 batches.
# Processing batch 1641 of 1784 batches.
# Processing batch 1642 of 1784 batches.
# Processing batch 1643 of 1784 batches.
# Processing batch 1644 of 1784 batches.
# Processing batch 1645 of 1784 batches.
# Processing batch 1646 of 1784 batches.
# Processing batch 1647 of 1784 batches.
# Processing batch 1648 of 1784 batches.
# Processing batch 1649 of 1784 batches.
# Processing batch 1650 of 1784 batches.
# Processing batch 1651 of 1784 batches.
# Processing batch 1652 of 1784 batches.
# Processing batch 1653 of 1784 batches.
# Processing batch 1654 of 1784 batches.
# Processing batch 1655 of 1784 batches.
# Processing batch 1656 of 1784 batches.
# Processing batch 1657 of 1784 batches.
# Processing batch 1658 of 1784 batches.
# Processing batch 1659 of 1784 batches.
# Processing batch 1660 of 1784 batches.
# Processing batch 1661 of 1784 batches.
# Processing batch 1662 of 1784 batches.
# Processing batch 1663 of 1784 batches.
# Processing batch 1664 of 1784 batches.
# Processing batch 1665 of 1784 batches.
# Processing batch 1666 of 1784 batches.
# Processing batch 1667 of 1784 batches.
# Processing batch 1668 of 1784 batches.
# Processing batch 1669 of 1784 batches.
# Processing batch 1670 of 1784 batches.
# Processing batch 1671 of 1784 batches.
# Processing batch 1672 of 1784 batches.
# Processing batch 1673 of 1784 batches.
# Processing batch 1674 of 1784 batches.
# Processing batch 1675 of 1784 batches.
# Processing batch 1676 of 1784 batches.
# Processing batch 1677 of 1784 batches.
# Processing batch 1678 of 1784 batches.
# Processing batch 1679 of 1784 batches.
# Processing batch 1680 of 1784 batches.
# Processing batch 1681 of 1784 batches.
# Processing batch 1682 of 1784 batches.
# Processing batch 1683 of 1784 batches.
# Processing batch 1684 of 1784 batches.
# Processing batch 1685 of 1784 batches.
# Processing batch 1686 of 1784 batches.
# Processing batch 1687 of 1784 batches.
# Processing batch 1688 of 1784 batches.
# Processing batch 1689 of 1784 batches.
# Processing batch 1690 of 1784 batches.
# Processing batch 1691 of 1784 batches.
# Processing batch 1692 of 1784 batches.
# Processing batch 1693 of 1784 batches.
# Processing batch 1694 of 1784 batches.
# Processing batch 1695 of 1784 batches.
# Processing batch 1696 of 1784 batches.
# Processing batch 1697 of 1784 batches.
# Processing batch 1698 of 1784 batches.
# Processing batch 1699 of 1784 batches.
# Processing batch 1700 of 1784 batches.
# Processing batch 1701 of 1784 batches.
# Processing batch 1702 of 1784 batches.
# Processing batch 1703 of 1784 batches.
# Processing batch 1704 of 1784 batches.
# Processing batch 1705 of 1784 batches.
# Processing batch 1706 of 1784 batches.
# Processing batch 1707 of 1784 batches.
# Processing batch 1708 of 1784 batches.
# Processing batch 1709 of 1784 batches.
# Processing batch 1710 of 1784 batches.
# Processing batch 1711 of 1784 batches.
# Processing batch 1712 of 1784 batches.
# Processing batch 1713 of 1784 batches.
# Processing batch 1714 of 1784 batches.
# Processing batch 1715 of 1784 batches.
# Processing batch 1716 of 1784 batches.
# Processing batch 1717 of 1784 batches.
# Processing batch 1718 of 1784 batches.
# Processing batch 1719 of 1784 batches.
# Processing batch 1720 of 1784 batches.
# Processing batch 1721 of 1784 batches.
# Processing batch 1722 of 1784 batches.
# Processing batch 1723 of 1784 batches.
# Processing batch 1724 of 1784 batches.
# Processing batch 1725 of 1784 batches.
# Processing batch 1726 of 1784 batches.
# Processing batch 1727 of 1784 batches.
# Processing batch 1728 of 1784 batches.
# Processing batch 1729 of 1784 batches.
# Processing batch 1730 of 1784 batches.
# Processing batch 1731 of 1784 batches.
# Processing batch 1732 of 1784 batches.
# Processing batch 1733 of 1784 batches.
# Processing batch 1734 of 1784 batches.
# Processing batch 1735 of 1784 batches.
# Processing batch 1736 of 1784 batches.
# Processing batch 1737 of 1784 batches.
# Processing batch 1738 of 1784 batches.
# Processing batch 1739 of 1784 batches.
# Processing batch 1740 of 1784 batches.
# Processing batch 1741 of 1784 batches.
# Processing batch 1742 of 1784 batches.
# Processing batch 1743 of 1784 batches.
# Processing batch 1744 of 1784 batches.
# Processing batch 1745 of 1784 batches.
# Processing batch 1746 of 1784 batches.
# Processing batch 1747 of 1784 batches.
# Processing batch 1748 of 1784 batches.
# Processing batch 1749 of 1784 batches.
# Processing batch 1750 of 1784 batches.
# Processing batch 1751 of 1784 batches.
# Processing batch 1752 of 1784 batches.
# Processing batch 1753 of 1784 batches.
# Processing batch 1754 of 1784 batches.
# Processing batch 1755 of 1784 batches.
# Processing batch 1756 of 1784 batches.
# Processing batch 1757 of 1784 batches.
# Processing batch 1758 of 1784 batches.
# Processing batch 1759 of 1784 batches.
# Processing batch 1760 of 1784 batches.
# Processing batch 1761 of 1784 batches.
# Processing batch 1762 of 1784 batches.
# Processing batch 1763 of 1784 batches.
# Processing batch 1764 of 1784 batches.
# Processing batch 1765 of 1784 batches.
# Processing batch 1766 of 1784 batches.
# Processing batch 1767 of 1784 batches.
# Processing batch 1768 of 1784 batches.
# Processing batch 1769 of 1784 batches.
# Processing batch 1770 of 1784 batches.
# Processing batch 1771 of 1784 batches.
# Processing batch 1772 of 1784 batches.
# Processing batch 1773 of 1784 batches.
# Processing batch 1774 of 1784 batches.
# Processing batch 1775 of 1784 batches.
# Processing batch 1776 of 1784 batches.
# Processing batch 1777 of 1784 batches.
# Processing batch 1778 of 1784 batches.
# Processing batch 1779 of 1784 batches.
# Processing batch 1780 of 1784 batches.
# Processing batch 1781 of 1784 batches.
# Processing batch 1782 of 1784 batches.
# Processing batch 1783 of 1784 batches.
# Processing batch 1784 of 1784 batches.
# Completed processing.

# %% [markdown]
# # Report False Positives, False Negatives, and overall accuracy

# %%
# Make sure there are no values in the 'diagnosis' column with the original wording of the 'Suicide' column
# If there are the LLM either messed up or skipped a tweet
condition = (tweet_df['diagnosis'] == 'Not Suicide post') | (tweet_df['diagnosis'] == 'Potential Suicide post ')
missed_df = tweet_df.loc[condition]

missed_cnt = missed_df.shape[0]

print("There are",missed_cnt,"cases where the LLM did not make a diagnosis (we are expecting 0).")
# Out:
# There are 0 cases where the LLM did not make a diagnosis (we are expecting 0).

# %%
# Identify the False Positives, these are cases where it suggeests to Follow-up on post and the ground truth said
# it is "Not Suicide post".
# The LLM sometimes get's confused and outputs sentence capitalized, no extra space, Potential suicide post
condition = (tweet_df['Suicide'] == 'Not Suicide post') & ((tweet_df['diagnosis'] == 'Follow-up') | (tweet_df['diagnosis'] == 'Potential suicide post'))
falsepos_df = tweet_df.loc[condition]

falsepos_cnt = falsepos_df.shape[0]

print("There are",falsepos_cnt,"false positives where a follow-up was recommended but the ground truth says it is not a suicide post")

for index, row in falsepos_df.iterrows():
    print("Tweet says: ",falsepos_df.loc[index,'Tweet'])
# Out:
# There are 58 false positives where a follow-up was recommended but the ground truth says it is not a suicide post
# Tweet says:  @jrkgirlnla Oh yes, I was reading that one
# Tweet says:  i'm tired,
# Tweet says:  @mikeyway http://twitpic.com/2tu6p - take care guys..!!
# Tweet says:  @jackhii n i got yr pic posing in the server room ..
# Tweet says:  Going to school and enjoying my last day as a 16 year old but too
# Tweet says:  @JonathanRKnight
# Tweet says:  @geuphers, you will fully bloom after all the hardships. i love u ):
# Tweet says:  1300 words...
# Tweet says:  RT @0mysky: If you find someone that makes you happy, enjoy it... life is not fair nor give many opportunities... https://t.co/dCBwDeQVH8
# Tweet says:  phone againn
# Tweet says:  @iwrotethis: Nope, you just caught me, cheers, I'm sure I will. Hope the sunshine holds out for you
# Tweet says:  today i almost kill myself because I almost hit by a car, thank lord.
# Tweet says:  @mizphenomenal god wrote that i just typed it
# Tweet says:  @annaarco I gained weight I'm one of those people everybody hates who can loose weight on a cake-and-cookies diet.
# Tweet says:  wanted to kill him.
# Tweet says:  Today i almost kill myself because I almost hit by a car.
# Tweet says:  @ShannonRenee
# Tweet says:  Last few hour in England...
# Tweet says:  @alonpeer 10x man any tips or ideas?
# Tweet says:  @xdcd What are you saying about yourself
# Tweet says:  @SLDalby Why YES xx
# Tweet says:  @Sam_Johnson I'm with ya there
# Tweet says:  @tommcfly http://twitpic.com/2y9c6 - hide it well from everyone!
# Tweet says:  @_aang21 I love you I love you ð¥â¤ï¸
# Tweet says:  @zergmoney tweet dreams
# Tweet says:  Found st thomas'and waiting
# Tweet says:  @chinewinelover ?????
# Tweet says:  arreeyy.. mad - o - wat..i'm wit u.. coz maine bhi.. intro hi start kiya
# Tweet says:  RT @Maddierawrk: My brother died from depression. He also frequently exercised, had supportive friends/family, was successful in school &amp; iâ¦
# Tweet says:  i have to go now.... make up duty for tomorrow...... goodnight to all....
# Tweet says:  What did you want me to say?
# Tweet says:  @dareanderae I love you ððð
# Tweet says:  I do not want all this.
# Tweet says:  @foodphilosophy magic rejuvenation...hmm I'm thinking Triple Oxygen Mask http://is.gd/kQkq and a Blissage105! Hang in there!
# Tweet says:  my sleep was disturbed. i am looking to end a career today
# Tweet says:  @gypsytrading
# Tweet says:  Oops again, its t w i t t e r....
# Tweet says:  RT @shxxyellowbin: Oh my heart hurts so good. I love you babe, so bad. @ikon_shxxbi https://t.co/aH5aObf60j
# Tweet says:  I don't care how frightening it will be, I want to go ahead.
# Tweet says:  accidentally her whole rib cage...well, nearly half of it! http://tinyurl.com/da72gp
# Tweet says:  @gimmethefife No one should ever be driven to the point of suicide... especially not by those you have done nothing but cared for..
# Tweet says:  The rapper LÃ¡zaro Leonado Rodriguez Betancul, best known for Viva Cuba free or pupito. This detainee in the area ofâ¦ https://t.co/oeWHow0l5a
# Tweet says:  I be asking god why do I keep loosing people in my life but I see why everyday you can't move ahead in life
# Tweet says:  @geeklitebeta Had to follow after reading that tweet about &quot;Why is it that every second ...&quot;
# Tweet says:  feel like running away, far away, in a great place where no one can find me.
# Tweet says:  RT @JoshYugen: @EntrataLorna @maymayentrata07 Hi tita @EntrataLorna now I know why she is the most humble and most genuine, even though itâ¦
# Tweet says:  Today i almost kill myself because I almost hit by a bus, thank Allah.
# Tweet says:  http://twitpic.com/2y7ho - edit = my mood
# Tweet says:  Want to kill him.
# Tweet says:  @sorinna Billie Holiday - I love this one Ã¯Â¿Â½TÃ¯Â¿Â½ainÃ¯Â¿Â½t NobodyÃ¯Â¿Â½s Business If I DoÃ¯Â¿Â½
# Tweet says:  wanted to kill her.
# Tweet says:  @AMyburgh No problem.
# Tweet says:  @Pixieguts really???? why? Call superman, he can save you!!!! We need ya!
# Tweet says:  Today i almost kill myself because I almost hit by a truck, thank God.
# Tweet says:  @aamelia lots and many. I illegaly downloaded them (h) BUT then lost them all. so now I only haz whatev ones tozz emails me why?
# Tweet says:  @gasi67 Not everything.
# Tweet says:  @eleahbaant I sure will.
# Tweet says:  i want to kill her.

# %%
condition = (tweet_df['Suicide'] == 'Potential Suicide post ') & (tweet_df['diagnosis'] == 'Ignore')
falseneg_df = tweet_df.loc[condition]

falseneg_cnt = falseneg_df.shape[0]

print("There are",falseneg_cnt,"false negatives where ignoring was recommended but the ground truth says it is a potential suicide post")

for index, row in falseneg_df.iterrows():
    print("Tweet says: ",falseneg_df.loc[index,'Tweet'])
# Out:
# There are 118 false negatives where ignoring was recommended but the ground truth says it is a potential suicide post
# Tweet says:  @dizzyhrvy that crap took me forever to put together. iâm going to go sleep for DAYS
# Tweet says:  I have an awful habit of avoiding writing papers by watching Instagram live videos of the kids I used to nanny forâ¦ https://t.co/NpfZu06gwy
# Tweet says:  RT @tamicakeyona: Being a single mommy was never part of the plan but I wake up everyday and do my shitðªð¾
# Tweet says:  I damn near hate smoking by myself but sometimes I like it cause I canât finish blunts and I be having some for later.
# Tweet says:  @EmisonNaomily but still,i highkey want him to be dead. He f killed peach and beck ugh.Candice is back so imma justâ¦ https://t.co/5pBYOKbtRc
# Tweet says:  @FrankDiElsi1 No I want him to get indicted &amp; watch the kids go to jail - I donât want him to die because the Trumpâ¦ https://t.co/BPMdXzujoo
# Tweet says:  @EricBoehlert Nothing to live for? Why? Because you have been nasty?
# Tweet says:  Rosie: âdoes he think Iâm gonna be single forever?â
# Tweet says:  RT @camphalfblood: Random commenter asked why I had such an extreme social warrior agenda in Magnus Chase. What he calls extreme social jusâ¦
# Tweet says:  RT @Mylingo11: Never get too attach cause  people wake up with  different feelings everyday.
# Tweet says:  Itâs been nearly three years, but I still feel that Kylo/Ben Solo doesnât deserve redemption. The man killed his owâ¦ https://t.co/a69qtrMkh7
# Tweet says:  All right so that's 200 for slytherin, 590 for hufflepuff and 520 for ravenclaw. Sadly I'll have to cut these sprinâ¦ https://t.co/jjn5aEzAtu
# Tweet says:  I die a little inside when I see an old person eating alone at a restaurant.
# Tweet says:  I hate repeating myself dawg. like damn.
# Tweet says:  @LessIsMoh @LaVendrickS We used to have one. But keeping a live wild animal in a cage surrounded by screaming drunkâ¦ https://t.co/swOCDlRqWC
# Tweet says:  jami: probably drunk driver coming onto on-coming traffic
# Tweet says:  RT @ZachStafford: I used to check the Forbes 30 Under 30 list every year to see if I could find a husband on it.
# Tweet says:  @homerunderbyemo,,Just checked out that Homerun Derby EP, it SLAPS  https://t.co/lrHB1FDz6t
# Tweet says:  RT @ghoulrunnings: ive said it before and ill say it again...waluigi sucks...he sounds and looks funny and thats it...theres nothing else tâ¦
# Tweet says:  me: *sees a car crash* i wonder how they crashed
# Tweet says:  RT @rosettalind55: @BrettCMajor1 I`m sick and tired of listening to @JustinTrudeau saying,"First and foremost ,we`re all here to work for Câ¦
# Tweet says:  This is correct. I, for one, absolutely do not want to live in a country with these fucking chuds. And I believe 25â¦ https://t.co/968xex7emJ
# Tweet says:  RT @mitchlafon: On This Day - November 12th 1976. Queen release single, Somebody to Love.
# Tweet says:  Being a single mommy was never part of the plan but I wake up everyday and do my shitðªð¾
# Tweet says:  RT @CoreyBBrooks: Living in the Hood can be really tough. I am tired of losing people to the violence. I will not give up! https://t.co/zjYâ¦
# Tweet says:  @shishirjha07,,@TVMohandasPai @PMOIndia @narendramodi Sir please tell does it suit to respected PM to tell âGive me 50 days and if things donât improve burn me aliveâ. If yes, then anyone can say that come we shall burn u. If not, I didnât see anyone dis-associating with this line.
# Tweet says:  Death scares tf out of me and i am not ready to die
# Tweet says:  I hate being by myself. Bc everything a damn music video
# Tweet says:  RT @TreyDiamonds: Hate the fact that Iâm damn near forced to figure everything out by myself but it must be done
# Tweet says:  I'm sick and tired of people putting so much energy into shitting on ships but they won't do the same to help a livâ¦ https://t.co/hyFuB3D04a
# Tweet says:  @AnitaHarrell19 @PeterParros I agree with everything except Benny. I'm tired of him. His character is boring and needs to die. IJS ð
# Tweet says:  mafumafu: "OH SH IT oH G OD" *scrambles to get everything he didn't pack*â¦
# Tweet says:  DANIEL WON!
# Tweet says:  RT @mjs03093641: TWEETS  are the real life,  awkward conversation starters between strangers.
# Tweet says:  @GlamLifeGuru Omg!!!! Theres fires and craziness goin on and you cant go home cause of it, and people are seriouslyâ¦ https://t.co/TFVjk6d2m7
# Tweet says:  Now playing J. Gardna ft 2 Pistols, Tone Trump &amp; Drop - Die Alone (Remix) (Dirty) on Street Style Radio
# Tweet says:  Living as a hardcore empath is so hard. I'm tired of being nice and putting emotional labor into those who are undeserving
# Tweet says:  @TheLoneDude1,United States,Why is everything so cancerous now. Like I cant even remember anymore if all this corporate crap has always been here or not but it's freaking stupid. I just want to watch a youtube video, I dont want to be force-fed a stupid product every time i go online like its cable TV.
# Tweet says:  I work with a lot of Russians in the SoCal office and they look completely miserable. Whenever I see them,â¦ https://t.co/f3hfTkoc4E
# Tweet says:  When I was in middle school I wanted to be emo don't judge
# Tweet says:  Oh my god if that Jim Acosta did to that woman was fucking abuse WHAT DO YOU THINK TRUMP HAS DONE TO FUCKING WOMENâ¦ https://t.co/U1eFGgIyuy
# Tweet says:  you guys are mean I would never wake up my friends
# Tweet says:  RT @axelsoup: the false information of hanyu never having to study like any other person as if he didn't have to wake up at 5AM to take entâ¦
# Tweet says:  RT andreamvaldez: "Trumpy Bear isnât your average meme-bred merch gone viral: It appeals to everyone and no one, itâ¦ https://t.co/yhS4IpnQTJ
# Tweet says:  I was called in yesterday at the Guidance Counselor's office. I thought I did something bad as my ID was blocked. Iâ¦ https://t.co/jka0bYtvG9
# Tweet says:  Damn I fucken hate shopping bc then I feel sooooo broke. Like I canât even enjoy myself anymore
# Tweet says:  @MonicaLewinsky @VanityFair Who cares? It happened and it is in the past. You have nothing to apologize for. Hillarâ¦ https://t.co/7hCvOUANCm
# Tweet says:  I only have like few of thesis chapter to go and like its oso like already filled in but my lazy ass being extra daâ¦ https://t.co/6Y6UzBwbsR
# Tweet says:  I think Iâm going to redecorate my living room but Iâm tired of moving stuff around
# Tweet says:  RT @delaneykazee: iâm so tired of living in a country that has become about taking sides. bitch can we all just love and respect each otherâ¦
# Tweet says:  Adam Sandler before he became shit predicted my future mental state...
# Tweet says:  Tired of living with childish people
# Tweet says:  i think it was my lack of saying anything at all that was pretty stupid when i met harry. i was acting all cool andâ¦ https://t.co/lpdqwGeI8J
# Tweet says:  asahi, giant and scared: PLEASE donât eat my ass spirits
# Tweet says:  Random thought #471729.I'm so glad I live in the time of GPS on my cell and navi in my car bc NOTHING confused me mâ¦ https://t.co/QwvphlC58Q
# Tweet says:  @janakidasa1 @BeecheyPat @central_cap @LevequeThots It is sickening. What is sickening is we elect ppl like the libâ¦ https://t.co/v8PzGBUglY
# Tweet says:  I just wanna goto that concert so damn bad but would hate myself if I spent $300 on that ticket right now
# Tweet says:  RT @llvv0i: I am not correcting anything I just live my life calmly and I have nothing to do with what is going on this miserable world
# Tweet says:  The one damn time I donât watch RAW, Becky and the Smackdown womenâs division attack the RAW womenâs division and Bâ¦ https://t.co/YSb2Eq2QAb
# Tweet says:  Canât believe I lost my damn car keys smh mind you the damn house key is on there ð this is the 2nd time my drunk aâ¦ https://t.co/EaZ8urlp7o
# Tweet says:  That skill takes time and iq. As a center he could run other bigs off the floor and force other teams to go small aâ¦ https://t.co/i0I3FKsgBt
# Tweet says:  anyway if you cant accept that ive MOVED ON FROM YOU SICKOS, go fuck yourself, ill just keep avoiding your sorry asses
# Tweet says:  me as a future therapist: damn :/ it be like that sometimes
# Tweet says:  RT @cparham65: Liberals say conservatives are evil. NOTHINGâs further from the truth! We believe in âlive &amp; let liveâ. Libs think that bigâ¦
# Tweet says:  @youractionlink,Utah,Want to take that perfect selfie? Hereâs what you should be looking for in your phone camera!
# Tweet says:  I literally hate myself for reading this damn book
# Tweet says:  @FortniteGame Better be adding bouncers back then. No way yâall are dumb enough to add this big a game change thenâ¦ https://t.co/2GGc72XP5a
# Tweet says:  @JosephSadowitz @trs63 @forensicpathmd @drjudymelinek @NRA I donât want your guns. Seriously. Iâm not sure who doesâ¦ https://t.co/1JZiyqovSd
# Tweet says:  #smallbizz #entrepreneur #entrepreneurlifestyle https://t.co/dEHV7DED58
# Tweet says:  We were tired from the concert so we ate noodles instead. After weâd eaten Emily saw photos that the restaurant hasâ¦ https://t.co/uqI5KXdJD6
# Tweet says:  @joyreaper @WolfensPride @BreitbartNews No doubt the Obamaâ fostered hate, division, chaos and anarchy! They are thâ¦ https://t.co/x5ch7odIZ9
# Tweet says:  said he has a job but has time for this shit, cant wait to see him next time i go on a maccas run!
# Tweet says:  @derekmusial,,@landonb94 @KidsSeeGhoats ok hold on, how can these numbers not be correct anymore if the video is two weeks old...? strength of schedule and record dont change too much in two weeks. and if yall dont care about top 4 why are you here? won your division, overranked to begin with, what else you want?
# Tweet says:  My work schedule for next week makes me want to DIE Iâm not ready
# Tweet says:  i just rlly cant wait for all old white ppl to fuckijg die out !!!! im so tired of gen x &amp; y and baby boomers literâ¦ https://t.co/ucZdBw2WHv
# Tweet says:  RT @BijinChihiro: 11æ11æ¥ ð¹#BLACKCOVE ðð¬#Family of 80 #dolphins decimated-7 died from stress-48 captured #freedom forever lost-Defenseless #â¦
# Tweet says:  Millwall v Blackburn travel purchased for live on Sky sports selection. Cant wait to go to the game with value!
# Tweet says:  I fucking get it that Iâm almost done with the semester but I feel like itâs too much shit I have to do. I feel likâ¦ https://t.co/rmKzCdSSNI
# Tweet says:  @MovinThatGearUp,Badlands/Smash Manor,@UltimxteCreator i guess
# Tweet says:  whoever replied i cant see it but just kno i said what i said and go see aquaman directed by james wan on dec 21 https://t.co/G1lMtPk12l
# Tweet says:  My grandpas wrist is bleeding really bad he cut it on accident ð©
# Tweet says:  I tried to be good and not buy food but i dead ass want chipotleâs chicken and rice rn
# Tweet says:  Damn my FBI agent must hate me. I saw this as soon as i asked myself âwhy are you always tired?â.. https://t.co/vTORJSqCx3
# Tweet says:  @WarcraftDevs  can u do something about demo holy fucking SHIT its been months without ANYTHING done do u not realiâ¦ https://t.co/g4m6reGxUg
# Tweet says:  RT @hankrsmith: Breaking off a serious relationship and saying, âI still want to be close friendsâ is like saying, âThe dog is dead, but Iâ¦
# Tweet says:  my wife: on his will it says he's left all his updog to you
# Tweet says:  @MagicMagid @Harryslaststand My G-Grandfather fought in WW1, earning the military medal at La Boisselle. Then in â3â¦ https://t.co/RerGDmgncL
# Tweet says:  I want a XBOX but I only want it for State of Decay and I dead ass donât have time to play it now. Really would be a pointless purchase
# Tweet says:  The leader of the band is tired&amp;his eyes are growing old
# Tweet says:  I hate when Iâm talking to myself and someoneâs like âhuh?â. Canât a girl have a conversation with herself in peace around here? god damn
# Tweet says:  RT @bakugousblackgf: nishinoya, small and ready to die: eat my ass spirits
# Tweet says:  RT @elsierosehewitt: how much anger must u be carrying to treat a stranger -whoâs life/struggles/battles you know nothing about- so poorly?â¦
# Tweet says:  RT @vanbrueghel: release my body
# Tweet says:  RT @trilllizard666: i swear some you motherfuckers WANT people to be horrible racist rapist homophobic pedophiles after they die and you giâ¦
# Tweet says:  I just wanna bring up Mac didnât die from cocaine mixed with fentanyl. He literally had a line. .âshit ainât been tâ¦ https://t.co/wUElVuw1CO
# Tweet says:  RT @WanNurSyaira: I never say my life is miserable, my life is pretty good not gonna lie. But what it seems to be a âprivilegedâ life may nâ¦
# Tweet says:  I've truly never been happier with my life :))) I'm rid of all the toxic people who brought me down :))) and thoseâ¦ https://t.co/g8KBt7lbtw
# Tweet says:  @PoorBoyOnline Was no reason for you to get banned 2k not right..Ronnie stay banning folks that do nothing but tryâ¦ https://t.co/zijyqCpXoE
# Tweet says:  @SowaTheArrogant Well he was partially right! I do want him to get sick and die and I would dance on his grave! Mayâ¦ https://t.co/5AzPorJUos
# Tweet says:  Hers my view from Canada ..for what its worth. More than half of you did..or he wouldnt be president..he treats his friends like shit..everyone is now his enemy..the USA has lost ALL respect from here..we want tou to build the wall here..cause we just dont trust you anymore..
# Tweet says:  RT @reckless: I am so jealous of this insane @TaylorLorenz story I want to die https://t.co/6RNqtfKlH5
# Tweet says:  man game of thrones is going to end next year and I'll have to wait 10 years for TWOW and ADOS to come out to get mâ¦ https://t.co/LIVsVvZC3M
# Tweet says:  I'm so tired of living pay check to pay check. If any scammer wanna DM please do ðð
# Tweet says:  RT @soieange: My ultimate goal is to not end up like all the miserable people around me who settled in life and are perpetually bitter abouâ¦
# Tweet says:  RT @MandalMadhura: @narendramodi Itâs a black Diwali for all of us who failed to #LetAvniLive. while we reached out to ur office with evideâ¦
# Tweet says:  RT @juliareyes004: @Ryankingry You or the picture?! Cus damn both be looking so good! ðð¤©
# Tweet says:  I do think homies doing the right thing &amp; deserves every dollar he will get. Steelers are silly for not paying himâ¦ https://t.co/ISoS0lcKTS
# Tweet says:  @vfpuk My G-Grandfather fought in WW1, earning the military medal at La Boisselle. Then in â39 the thought of fightâ¦ https://t.co/gh1oCMsz7Q
# Tweet says:  Got banned in my boy Clayster's chat by his thot gf @Lunalovebadxo for saying its sad how CoD pros wake up at 4 PMâ¦ https://t.co/9FJuA5dlC9
# Tweet says:  I swear it doesnât matter what time I go to sleep my body forever wakes up tired
# Tweet says:  @ad8871,Michigan, USA,@MelaynaLokosky @ravenvanderrave Hi, I know you are scrambling to escape with no time to even save your pets or family heirlooms lest you burn alive. I know entire towns have burned to the ground and hundreds of thousands are homeless evacuees. But please take some time to let ME know how to help
# Tweet says:  @MegamanTV @tom_wilso @NHL @Capitals i play hockey, ive gotten penalties like that. dead play or not, you cant go iâ¦ https://t.co/J9vcMvoE23
# Tweet says:  RT @AshleySantini: I go on YouTube to binge watch David dobrik wholeheartedly knowing Iâm going to be sad bc i cant marry him or Scotty orâ¦
# Tweet says:  RT @Elixeon: Just want to say that just cause a song isn't charting, doesn't mean its dead. Stans online care about charts way more than GPâ¦
# Tweet says:  RT @myonlyTAEger: Knets try to describe how V looks like in real life
# Tweet says:  Donât break other people down just because they may seem âweakerâ than you. If someoneâs eyes are 20/20 that doesnââ¦ https://t.co/DHtb9JZKxE
# Tweet says:  Me knowing damn well that I will hate myself for taking a 7:30 but doing it anyways https://t.co/FRhjVbgkUw
# Tweet says:  damn, what is this crazy life of mine

# %%
#a
condition = (tweet_df['Suicide'] == 'Potential Suicide post ') & (tweet_df['diagnosis'] == 'Follow-up')
bothagree_psp_df = tweet_df.loc[condition]
bothagree_psp_cnt = bothagree_psp_df.shape[0]
print ("Both agree on potential suicide post = ", bothagree_psp_cnt, "times.")

#d
condition = (tweet_df['Suicide'] == 'Not Suicide post') & (tweet_df['diagnosis'] == 'Ignore')
bothagree_npsp_df = tweet_df.loc[condition]
bothagree_npsp_cnt = bothagree_npsp_df.shape[0]
print ("Both agree on not suicide post = ", bothagree_npsp_cnt, "times.")

#b 
condition = (tweet_df['Suicide'] == 'Potential Suicide post ') & (tweet_df['diagnosis'] == 'Ignore')
psp_vs_ignore_df = tweet_df.loc[condition]
psp_vs_ignore_cnt = psp_vs_ignore_df.shape[0]
print ("Ground truth says potential suicide post and LLM disagrees = ", psp_vs_ignore_cnt, "times.")

#c
condition = (tweet_df['Suicide'] == 'Not Suicide post') & (tweet_df['diagnosis'] == 'Follow-up')
npsp_vs_followup_df = tweet_df.loc[condition]
npsp_vs_followup_cnt = npsp_vs_followup_df.shape[0]
print ("Ground truth says not a suicide post and LLM disagrees = ", npsp_vs_followup_cnt, "times.")

observed_agreement = (bothagree_psp_cnt + bothagree_npsp_cnt) / \
                (bothagree_psp_cnt + bothagree_npsp_cnt + psp_vs_ignore_cnt + npsp_vs_followup_cnt)

print ("Calculated Observed Agreement =", observed_agreement)

chance_agreement = \
    ((bothagree_psp_cnt + psp_vs_ignore_cnt) * (bothagree_psp_cnt + npsp_vs_followup_cnt) + \
     (npsp_vs_followup_cnt + bothagree_npsp_cnt) * (bothagree_npsp_cnt + psp_vs_ignore_cnt)) / \
    ((bothagree_psp_cnt + bothagree_npsp_cnt + psp_vs_ignore_cnt + npsp_vs_followup_cnt) * \
     (bothagree_psp_cnt + bothagree_npsp_cnt + psp_vs_ignore_cnt + npsp_vs_followup_cnt))

print ("Calculated Chance Agreement =", chance_agreement)

kappa = (observed_agreement - chance_agreement) / (1 - chance_agreement)

print ("Cohen's Kappa=", kappa)
# Out:
# Both agree on potential suicide post =  541 times.
# Both agree on not suicide post =  1068 times.
# Ground truth says potential suicide post and LLM disagrees =  118 times.
# Ground truth says not a suicide post and LLM disagrees =  58 times.
# Calculated Observed Agreement = 0.9014005602240897
# Calculated Chance Agreement = 0.5430178345848143
# Cohen's Kappa= 0.7842378822676176

# %%
# Let's see what the accuracy relative to ground truth looks like
totalerr_cnt = falsepos_cnt + falseneg_cnt
print ("There were a total of",totalerr_cnt,"errors made relative to ground truth.")
print ("Accuracy is at",(1-totalerr_cnt/tweet_df.shape[0])*100.0,"%")
# Out:
# There were a total of 176 errors made relative to ground truth.
# Accuracy is at 90.14005602240897 %

# %% [markdown]
# # Load a VectorstoreIndex with all the tweets to ask inter-tweet questions

# %%
# Now, to show the power of a vector index, each tweet will be loaded.
# The tweets will be one document each vectorized and with embeddings
# There is no need to split the documents

print ("Build a list of documents, one per Tweet...")
doclist = []
for tweetnum in range(tweet_df.shape[0]): #tweet_df.shape[0]):  
    raw_documents = Document(page_content=str(tweet_df.iloc[tweetnum].to_dict()))
    doclist.append(raw_documents)

print("Working on loading tweets into the VectorstoreIndex using default settings for Chroma.")
index = VectorstoreIndexCreator(vectorstore_kwargs={"persist_directory":None}).from_documents(doclist)
# Out:
# Build a list of documents, one per Tweet...
# Working on loading tweets into the VectorstoreIndex using default settings for Chroma.

# %% [markdown]
# ## Show a few (3) questions and the answers given

# %%
query = "From the tweets you know show tweets most like: I am tired and going to sleep forever."
print("Asking: ", query)
response = index.query(query, llm=ChatOpenAI(model_name="gpt-3.5-turbo"))
print("Response: ",response)
# Out:
# Asking:  From the tweets you know show tweets most like: I am tired and going to sleep forever.
# Response:  Tweets like "i wanna go to sleep forever and never wake up im so tired" are most similar to the statement "I am tired and going to sleep forever."

# %%
query = "Are there tweets being analyzed that are different than one like this: I am in love, and so happy. Give a few examples."
print("Asking: ", query)
response = index.query(query, llm=ChatOpenAI(model_name="gpt-3.5-turbo"))
print("Response: ",response)
# Out:
# Asking:  Are there tweets being analyzed that are different than one like this: I am in love, and so happy. Give a few examples.
# Response:  Yes, there are tweets being analyzed that are different from the example you provided. Here are a few examples:
#
# 1. "A lot of my tweets are about being lost & miserable but it's not always all it's cracked out to be lol my life is a..." (Potential Suicide post)
# 2. "please somebody come fucking kill me im so in LOVE!!!" (Potential Suicide post)
# 3. "If you find someone that makes you happy, enjoy it... life is not fair nor give many opportunities..." (Not Suicide post)
# 4. "I've truly never been happier with my life :))) I'm rid of all the toxic people who brought me down :))) and those..." (Potential Suicide post)
#
# Please note that the diagnosis of each tweet is provided based on the given context.

# %%
query = "Categorize the tweets according to emotional states and give an example of each category."
print("Asking: ", query)
response = index.query(query, llm=ChatOpenAI(model_name="gpt-3.5-turbo"))
print("Response: ",response)
# Out:
# Asking:  Categorize the tweets according to emotional states and give an example of each category.
# Response:  Based on the provided context, the tweets can be categorized into the following emotional states:
#
# 1. Feeling overwhelmed: "almost broke down at class just because the most negative thoughts are kicking in and I'm mf tired of living hahahahahahahah"
# 2. Feeling betrayed and hurt: "I was drinking and crying my night away as usual to find out my ex is fucking a girl in his bed so I tried to killâ¦"
# 3. Feeling hopeless: "Tired of living like this"
# 4. Feeling lonely: "I feel so lonely"
#
# Example of each category:
# 1. Feeling overwhelmed: The tweet mentions negative thoughts and being tired of living, indicating a sense of being overwhelmed by emotions and thoughts.
# 2. Feeling betrayed and hurt: The tweet describes the person's reaction to finding out about their ex-partner being with someone else, resulting in intense emotions and even a suicide attempt.
# 3. Feeling hopeless: The tweet expresses a general feeling of being tired of living, suggesting a lack of hope or optimism.
# 4. Feeling lonely: The tweet specifically mentions feeling lonely, indicating a sense of isolation and longing for connection.
